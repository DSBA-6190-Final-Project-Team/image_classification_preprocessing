# %% [markdown]
# # Note
# This Notebook Lost Source Control of the Images in S3. A New Notebook will be develoepd to re-do the preprocessing of the distracted driver images.

# %% [markdown]
# # Background and Proposed Method

# %% [markdown]
# ## Data
# The data set is the [State Farm Distracted Driver](https://www.kaggle.com/c/state-farm-distracted-driver-detection) dataset hosted on Kaggle.
#
# The Kaggle page provides three items:
# 1. a list of training images, their subject (driver) id, and class id (CSV)
# 2. a sample_submission.csv - a sample submission file in the correct format (CSV)
# 3. zipped folder of all (train/test) images (ZIP)
#
# The data that the algorithm will train on is in the zipped folder. Within the folder are two sub-directories, train and test. The train directory contains the training set of the data, with each class of image within its own subfolder. The test directory contains only images, not seperated by class. It is to be used to score the final algorithm for Kaggle.

# %% [markdown]
# ## Environment
# The current plan is to generate a model in Amazon Sagemaker. A Amazon Sagemaker Notebook, using the Sagemaker Image Classification algorithm, will be used to generate a model. The Notebook will also deplot the model, once trained.

# %% [markdown]
# ## Algorithm
# The Amazon Sagemaker Image Classification Algorithm has four main inputs:
# 1. training set of images
# 2. validation set of images
# 3. lst/rec file for trianing set
# 4. lst/rec file for validation set
#
# The lst or rec file (either acceptable) functions as a mapping resource, connecting each image to the image location and image class.

# %% [markdown]
# ## Data Preparation
# The provided test set will not be useful as a validation set for the algorithm. The Sagemaker Image Classification Algorithm requires a labeled validation set. Therefore, we will need to derive our own validation set from the provided training set.
#
# Based on the [Towards Data blog post](https://towardsdatascience.com/how-i-tackled-my-first-kaggle-challenge-using-deep-learning-part-1-b0da29e1351b) walking through the same data, we are not going to split the training/validation data strictly randomly. Instead, we will split the drivers randomly, so that a unique driver only exists in either the training or the validation set.
#
# ### Training / validation Set
# The first step will be developing a list of unique drivers. We should also check the amount of pictures per driver to get an idea of how even the split of pictures per driver is.
#
# Then, we will generate a list of training and validation drivers by randomly selecting from the unique list of drivers, using a 80/20 split.
#
# ### LST/REC File Development
# The Image Classification Algorithm requires a file which maps the  images to the associated classes, for the training and validation sets. This can be in the form of a lst or rec file.
#
# There is python script available [here](https://mxnet.apache.org/api/faq/recordio) which will create these files. But these files must on your machine locally. I have already exported the files to S3. Therefore, I will need to re-download the files to a local machine and run this script.
#
# #### Training / Validation in the Mapping File
# After the script has been generated, we will then need to seperate the training and validation images into seperate, labeled, folders.

# %% [markdown]
# # Import

# %% [markdown]
# ## Library / Packages

# %%
import pandas as pd
import random 
import os
import shutil
import boto3

from filecmp import dircmp

# %% [markdown]
# ## Data

# %%
url = "https://raw.githubusercontent.com/DSBA-6190-Final-Project-Team/DSBA-6190_Final-Project/master/wine_predict/data/driver_imgs_list.csv"
path_file = 'data/driver_imgs_list.csv'

df_driver_index = pd.read_csv(path_file)

# %% [markdown]
# # EDA

# %%
df_driver_index.shape
# Out:
# (22424, 3)

# %%
df_driver_index.head(5)
# Out:
#   subject classname            img
# 0    p002        c0  img_44733.jpg
# 1    p002        c0  img_72999.jpg
# 2    p002        c0  img_25094.jpg
# 3    p002        c0  img_69092.jpg
# 4    p002        c0  img_92629.jpg

# %%
df_driver_index.columns
# Out:
# Index(['subject', 'classname', 'img'], dtype='object')

# %% [markdown]
# The following lists each unique driver along with the number of different classname and images are associated with each. Note the number of classnames is not unique, so the images an classnames have equal frequencies.

# %%
drivers_gb = df_driver_index.groupby(['subject'])
drivers_gb.count()
# Out:
#          classname   img
# subject
# p002           725   725
# p012           823   823
# p014           876   876
# p015           875   875
# p016          1078  1078
# p021          1237  1237
# p022          1233  1233
# p024          1226  1226
# p026          1196  1196
# p035           848   848
# p039           651   651
# p041           605   605
# p042           591   591
# p045           724   724
# p047           835   835
# p049          1011  1011
# p050           790   790
# p051           920   920
# p052           740   740
# p056           794   794
# p061           809   809
# p064           820   820
# p066          1034  1034
# p072           346   346
# p075           814   814
# p081           823   823

# %% [markdown]
# We will set the training/validation split ratio.

# %%
train_val_split = 0.3

# %% [markdown]
# To split the data into training and validation sets, we'll need a unique index of drivers. We don't need the frequency counts.
#
# We will create a shuffled list of unique drivers.

# %%
drivers_unique = drivers_gb.groups.keys()
drivers_unique = list(drivers_unique)

random.Random(5590).shuffle(drivers_unique)
print(drivers_unique)
# Out:
# ['p049', 'p022', 'p012', 'p075', 'p045', 'p072', 'p026', 'p042', 'p015', 'p039', 'p047', 'p081', 'p052', 'p014', 'p021', 'p035', 'p061', 'p064', 'p066', 'p056', 'p002', 'p041', 'p024', 'p016', 'p051', 'p050']

# %% [markdown]
# validation we'll set the list of drivers in the train set and the test set.

# %%
num_drivers_val = round(len(drivers_unique)*train_val_split)
#print(num_drivers_val)
num_drivers_train = len(drivers_unique) - num_drivers_val
#print(num_drivers_train)

# %%
drivers_val = drivers_unique[:num_drivers_val]
print(drivers_val)
# Out:
# ['p049', 'p022', 'p012', 'p075', 'p045', 'p072', 'p026', 'p042']

# %%
drivers_train = drivers_unique[-num_drivers_train:]
print(drivers_train)
# Out:
# ['p015', 'p039', 'p047', 'p081', 'p052', 'p014', 'p021', 'p035', 'p061', 'p064', 'p066', 'p056', 'p002', 'p041', 'p024', 'p016', 'p051', 'p050']

# %% [markdown]
# # Training and Validation Image Lists
# We'll now create two lists, one list of every image file name associated with the trainging set, another list associated with the test set.
#
# We will use these lists to filter the overall lst mapping file.

# %%
df_images_val = df_driver_index[df_driver_index['subject'].isin(drivers_val)]
df_images_training = df_driver_index[~df_driver_index['subject'].isin(df_images_val)]

# %%
print(df_images_training.shape)
df_images_training.head()
# Out:
# (22424, 3)
#   subject classname            img
# 0    p002        c0  img_44733.jpg
# 1    p002        c0  img_72999.jpg
# 2    p002        c0  img_25094.jpg
# 3    p002        c0  img_69092.jpg
# 4    p002        c0  img_92629.jpg

# %%
print(df_images_val.shape)
df_images_val.head()
# Out:
# (6738, 3)
#     subject classname            img
# 725    p012        c0  img_10206.jpg
# 726    p012        c0  img_27079.jpg
# 727    p012        c0  img_50749.jpg
# 728    p012        c0  img_97089.jpg
# 729    p012        c0  img_37741.jpg

# %% [markdown]
# # LST Files
# ## Generate Overall List
#
# The Sagemaker Image Classification Algorithm requires eitehr an LST or REC file as input, one for the training and one for the validation set. The file acts as a mapping function, connecting the image of each set to the image file location and the image class.
#
# First we will develop a list, overall.lst, that catalogs every image. We will then import the list, and generate two new lists, train.lst and validation.lst. The train and validation files will be subsets of overall.lst, filtered based on the training and validation split done above.
#
# The lst tool is im2rec.py, found here: [https://mxnet.apache.org/api/faq/recordio](https://mxnet.apache.org/api/faq/recordio)

# %%
# %run tools/im2rec.py overall imgs/train --list --recursive
# Out:
# c0 0
# c1 1
# c2 2
# c3 3
# c4 4
# c5 5
# c6 6
# c7 7
# c8 8
# c9 9

# %% [markdown]
# ## Generate Training / Validation List
# We will now generate the lst files for the training and validation sets.
#
# We will also create sub-sampled training and validation lists, for preliminary work. To do this we first need to sample the overall list of images. Then, we will filter the training and validation **lst** files with the sampled overall list. In the sample, we will take the same sample, by percentage, of each unique driver.

# %% [markdown]
# ### Upload Overall List

# %%
file_name = 'lst_files/overall.lst'

df_overall = pd.read_csv(file_name, sep='\t', header = None)

# %%
columns = ('index', 'classname', 'location')
df_overall.columns = columns
df_overall.head()
df_overall = df_overall.sort_values(by=['location'])

df_overall
# Out:
#        index  classname           location
# 18606      0        0.0  c0\img_100026.jpg
# 6202       1        0.0   c0\img_10003.jpg
# 778        2        0.0  c0\img_100050.jpg
# 9516       3        0.0  c0\img_100074.jpg
# 1452       4        0.0   c0\img_10012.jpg
# ...      ...        ...                ...
# 8154   22419        9.0   c9\img_99761.jpg
# 4375   22420        9.0   c9\img_99801.jpg
# 2061   22421        9.0   c9\img_99927.jpg
# 11577  22422        9.0    c9\img_9993.jpg
# 4464   22423        9.0   c9\img_99949.jpg
#
# [22424 rows x 3 columns]

# %% [markdown]
# For use in the Amazon environment, we need to invert the slashes in the location column.

# %%
df_overall['location'] = df_overall['location'].str.replace('\\','/')

# %%
df_overall.head()
# Out:
#        index  classname           location
# 18606      0        0.0  c0/img_100026.jpg
# 6202       1        0.0   c0/img_10003.jpg
# 778        2        0.0  c0/img_100050.jpg
# 9516       3        0.0  c0/img_100074.jpg
# 1452       4        0.0   c0/img_10012.jpg

# %% [markdown]
# ### Create Image Column

# %% [markdown]
# We will create a new column, using the location column and char_location column, which will just list the image file name.

# %%
# Create Dataframe of split image location
location_split = df_overall.location.str.split('/', expand=True)

# Add Back Image File Name to original dataframe.
df_overall['img'] = location_split[1]
df_overall.head()
# Out:
#        index  classname           location             img
# 18606      0        0.0  c0/img_100026.jpg  img_100026.jpg
# 6202       1        0.0   c0/img_10003.jpg   img_10003.jpg
# 778        2        0.0  c0/img_100050.jpg  img_100050.jpg
# 9516       3        0.0  c0/img_100074.jpg  img_100074.jpg
# 1452       4        0.0   c0/img_10012.jpg   img_10012.jpg

# %% [markdown]
# ### Filter Overall List
# We will now filter the overall list to create the training and validation set lists. Then, we will drop the img column so that when these files are exported, they maintain the correct **lst** format.

# %% [markdown]
# #### Total Data Set

# %%
df_train_lst_all = df_overall[df_overall['img'].isin(df_images_training['img'])]
df_train_lst = df_train_lst_all.drop(['img'], axis=1)

#Checks
print(df_train_lst.shape)
df_train_lst.head()
# Out:
# (22424, 3)
#        index  classname           location
# 18606      0        0.0  c0/img_100026.jpg
# 6202       1        0.0   c0/img_10003.jpg
# 778        2        0.0  c0/img_100050.jpg
# 9516       3        0.0  c0/img_100074.jpg
# 1452       4        0.0   c0/img_10012.jpg

# %%
df_val_lst_all = df_overall[df_overall['img'].isin(df_images_val['img'])]
df_val_lst = df_val_lst_all.drop(['img'], axis=1)

#Checks
print(df_val_lst.shape)
df_val_lst.head()
# Out:
# (6738, 3)
#        index  classname           location
# 6202       1        0.0   c0/img_10003.jpg
# 778        2        0.0  c0/img_100050.jpg
# 17543      5        0.0  c0/img_100145.jpg
# 21656      9        0.0  c0/img_100337.jpg
# 3034      10        0.0  c0/img_100456.jpg

# %% [markdown]
# #### Sampled Data Set

# %%
sample_frac = 0.1

# %%
# Create Sample of Training Images
df_images_training_sample = df_images_training.groupby('subject').apply(pd.DataFrame.sample, 
                                                                        frac=sample_frac)

df_images_training_sample.shape
# Out:
# (2242, 3)

# %%
# Create Sample of Test Images
df_images_val_sample = df_images_val.groupby('subject').apply(pd.DataFrame.sample, 
                                                                        frac=sample_frac)

df_images_val_sample.shape
# Out:
# (673, 3)

# %% [markdown]
# ##### Training

# %%
df_train_sample_lst_all = df_overall[df_overall['img'].isin(df_images_training_sample['img'])]
df_train_sample_lst = df_train_sample_lst_all.drop(['img'], axis=1)

#Checks
print(df_train_sample_lst.shape)
df_train_sample_lst.head()
# Out:
# (2242, 3)
#        index  classname           location
# 7843      19        0.0  c0/img_100824.jpg
# 12227     35        0.0  c0/img_101414.jpg
# 3404      41        0.0  c0/img_101668.jpg
# 11047     48        0.0  c0/img_101938.jpg
# 5772      62        0.0   c0/img_10570.jpg

# %% [markdown]
# ##### Validation

# %%
df_val_sample_lst_all = df_overall[df_overall['img'].isin(df_images_val_sample['img'])]
df_val_sample_lst = df_val_sample_lst_all.drop(['img'], axis=1)

#Checks
print(df_val_sample_lst.shape)
df_val_sample_lst.head()
# Out:
# (673, 3)
#        index  classname           location
# 6202       1        0.0   c0/img_10003.jpg
# 13191     12        0.0   c0/img_10053.jpg
# 20482     24        0.0  c0/img_101032.jpg
# 13616     50        0.0   c0/img_10206.jpg
# 6154      64        0.0   c0/img_10609.jpg

# %% [markdown]
# ### Export

# %% [markdown]
# #### Sample Subset

# %%
# Training
file_name = "lst_files/train_sample.lst"
df_train_sample_lst.to_csv(file_name, sep='\t', index=None, header=None)

# %%
# df_val_sample_lst
file_name = "lst_files/validation_sample.lst"
df_val_sample_lst.to_csv(file_name, sep='\t', index=None, header=None)

# %% [markdown]
# #### Total Sample

# %%
# Training
file_name = "lst_files/train.lst"
df_train_lst.to_csv(file_name, sep='\t', index=None, header=None)

# %%
# df_val_sample_lst
file_name = "lst_files/validation.lst"
df_val_lst.to_csv(file_name, sep='\t', index=None, header=None)

# %% [markdown]
# ## Move Files in S3
#
# The concepts for "moving" files in S3 are taken from this blog post:
#
# [https://medium.com/plusteam/move-and-rename-objects-within-an-s3-bucket-using-boto-3-58b164790b78](https://medium.com/plusteam/move-and-rename-objects-within-an-s3-bucket-using-boto-3-58b164790b78).

# %% [markdown]
#  In order to interact with AWS entities outside of the AWS system, we need to add AWS User credentials locally. The AWS User also needs to have the correct IAM permissions.
#
# In order to avoid manually adding User credentials, I maintain a credentials file in Google Drive. We will copy the credentials file (INI file, no extension, per documentation) to the correct local directory.
#
# I was unable to figure out a way to connect to my google drive and do this via code, so the credentials file was copied manually.

# %% [markdown]
# ### Define S3 Parameters

# %%
profile = 'dsba_6190_proj_4'
region = 'us-east-1'
bucket = 'dsba-6190-final-team-project'
prefix_train = 'imgs/train'
prefix_val = 'imgs/validation'

# %%
session = boto3.session.Session(profile_name=profile, region_name = region)
s3_client = session.client('s3')

# %% [markdown]
# ### Transfer Images

# %% [markdown]
# To copy everything correctly, we'll have to iterate over a list of images we know we want to move. We have that list in dataframe form (**df_val_lst**). We'll first test that we can iterate over the dataframe and generate the necessary s3 file locations.

# %% [markdown]
# The following code chunk is old. I am keeping it in case the actions used here need to be copied.

# %%
# Old
'''
#Set Row and Column Index
row_index = 5590
col_index = df_val_lst.columns.get_loc("location")

# Create relative path to image
img_loc = df_val_lst.iloc[row_index, col_index].replace("\\","/")

# Create source and destination paths in S3 to image
src_test = os.path.join(s3train, img_loc)
dst_test = os.path.join(s3validation, img_loc)
print('src: {}'.format(src_test))
print('dst: {}'.format(dst_test))
'''
# Out:
# '\n#Set Row and Column Index\nrow_index = 5590\ncol_index = df_val_lst.columns.get_loc("location")\n\n# Create relative path to image\nimg_loc = df_val_lst.iloc[row_index, col_index].replace("\\","/")\n\n# Create source and destination paths in S3 to image\nsrc_test = os.path.join(s3train, img_loc)\ndst_test = os.path.join(s3validation, img_loc)\nprint(\'src: {}\'.format(src_test))\nprint(\'dst: {}\'.format(dst_test))\n'

# %%
for index, row in df_val_lst.iterrows():
    src_key = os.path.join(prefix_train,row['location']).replace("\\","/")
    dst_key = os.path.join(prefix_val, row['location']).replace("\\","/")
    print()
    print('Source Key:\t\t{}'.format(src_key))
    print('Destination Key:\t{}'.format(dst_key))
# Out:
# Source Key:		imgs/train/c0/img_10003.jpg
# Destination Key:	imgs/validation/c0/img_10003.jpg
#
# Source Key:		imgs/train/c0/img_100050.jpg
# Destination Key:	imgs/validation/c0/img_100050.jpg
#
# Source Key:		imgs/train/c0/img_100145.jpg
# Destination Key:	imgs/validation/c0/img_100145.jpg
#
# Source Key:		imgs/train/c0/img_100337.jpg
# Destination Key:	imgs/validation/c0/img_100337.jpg
#
# Source Key:		imgs/train/c0/img_100456.jpg
# Destination Key:	imgs/validation/c0/img_100456.jpg
#
# Source Key:		imgs/train/c0/img_10053.jpg
# Destination Key:	imgs/validation/c0/img_10053.jpg
#
# Source Key:		imgs/train/c0/img_100598.jpg
# Destination Key:	imgs/validation/c0/img_100598.jpg
#
# Source Key:		imgs/train/c0/img_100605.jpg
# Destination Key:	imgs/validation/c0/img_100605.jpg
#
# Source Key:		imgs/train/c0/img_100828.jpg
# Destination Key:	imgs/validation/c0/img_100828.jpg
#
# Source Key:		imgs/train/c0/img_10092.jpg
# Destination Key:	imgs/validation/c0/img_10092.jpg
#
# Source Key:		imgs/train/c0/img_101032.jpg
# Destination Key:	imgs/validation/c0/img_101032.jpg
#
# Source Key:		imgs/train/c0/img_101414.jpg
# Destination Key:	imgs/validation/c0/img_101414.jpg
#
# Source Key:		imgs/train/c0/img_101613.jpg
# Destination Key:	imgs/validation/c0/img_101613.jpg
#
# Source Key:		imgs/train/c0/img_101673.jpg
# Destination Key:	imgs/validation/c0/img_101673.jpg
#
# Source Key:		imgs/train/c0/img_101859.jpg
# Destination Key:	imgs/validation/c0/img_101859.jpg
#
# Source Key:		imgs/train/c0/img_102025.jpg
# Destination Key:	imgs/validation/c0/img_102025.jpg
#
# Source Key:		imgs/train/c0/img_10206.jpg
# Destination Key:	imgs/validation/c0/img_10206.jpg
#
# Source Key:		imgs/train/c0/img_10225.jpg
# Destination Key:	imgs/validation/c0/img_10225.jpg
#
# Source Key:		imgs/train/c0/img_104.jpg
# Destination Key:	imgs/validation/c0/img_104.jpg
#
# Source Key:		imgs/train/c0/img_10446.jpg
# Destination Key:	imgs/validation/c0/img_10446.jpg
#
# Source Key:		imgs/train/c0/img_1053.jpg
# Destination Key:	imgs/validation/c0/img_1053.jpg
#
# Source Key:		imgs/train/c0/img_10570.jpg
# Destination Key:	imgs/validation/c0/img_10570.jpg
#
# Source Key:		imgs/train/c0/img_10609.jpg
# Destination Key:	imgs/validation/c0/img_10609.jpg
#
# Source Key:		imgs/train/c0/img_10652.jpg
# Destination Key:	imgs/validation/c0/img_10652.jpg
#
# Source Key:		imgs/train/c0/img_10741.jpg
# Destination Key:	imgs/validation/c0/img_10741.jpg
#
# Source Key:		imgs/train/c0/img_10792.jpg
# Destination Key:	imgs/validation/c0/img_10792.jpg
#
# Source Key:		imgs/train/c0/img_1083.jpg
# Destination Key:	imgs/validation/c0/img_1083.jpg
#
# Source Key:		imgs/train/c0/img_11259.jpg
# Destination Key:	imgs/validation/c0/img_11259.jpg
#
# Source Key:		imgs/train/c0/img_11474.jpg
# Destination Key:	imgs/validation/c0/img_11474.jpg
#
# Source Key:		imgs/train/c0/img_11532.jpg
# Destination Key:	imgs/validation/c0/img_11532.jpg
#
# Source Key:		imgs/train/c0/img_11914.jpg
# Destination Key:	imgs/validation/c0/img_11914.jpg
#
# Source Key:		imgs/train/c0/img_12114.jpg
# Destination Key:	imgs/validation/c0/img_12114.jpg
#
# Source Key:		imgs/train/c0/img_1215.jpg
# Destination Key:	imgs/validation/c0/img_1215.jpg
#
# Source Key:		imgs/train/c0/img_1236.jpg
# Destination Key:	imgs/validation/c0/img_1236.jpg
#
# Source Key:		imgs/train/c0/img_12458.jpg
# Destination Key:	imgs/validation/c0/img_12458.jpg
#
# Source Key:		imgs/train/c0/img_12642.jpg
# Destination Key:	imgs/validation/c0/img_12642.jpg
#
# Source Key:		imgs/train/c0/img_1267.jpg
# Destination Key:	imgs/validation/c0/img_1267.jpg
#
# Source Key:		imgs/train/c0/img_12772.jpg
# Destination Key:	imgs/validation/c0/img_12772.jpg
#
# Source Key:		imgs/train/c0/img_12868.jpg
# Destination Key:	imgs/validation/c0/img_12868.jpg
#
# Source Key:		imgs/train/c0/img_13033.jpg
# Destination Key:	imgs/validation/c0/img_13033.jpg
#
# Source Key:		imgs/train/c0/img_13121.jpg
# Destination Key:	imgs/validation/c0/img_13121.jpg
#
# Source Key:		imgs/train/c0/img_13628.jpg
# Destination Key:	imgs/validation/c0/img_13628.jpg
#
# Source Key:		imgs/train/c0/img_1367.jpg
# Destination Key:	imgs/validation/c0/img_1367.jpg
#
# Source Key:		imgs/train/c0/img_13922.jpg
# Destination Key:	imgs/validation/c0/img_13922.jpg
#
# Source Key:		imgs/train/c0/img_13935.jpg
# Destination Key:	imgs/validation/c0/img_13935.jpg
#
# Source Key:		imgs/train/c0/img_14027.jpg
# Destination Key:	imgs/validation/c0/img_14027.jpg
#
# Source Key:		imgs/train/c0/img_14047.jpg
# Destination Key:	imgs/validation/c0/img_14047.jpg
#
# Source Key:		imgs/train/c0/img_1421.jpg
# Destination Key:	imgs/validation/c0/img_1421.jpg
#
# Source Key:		imgs/train/c0/img_14223.jpg
# Destination Key:	imgs/validation/c0/img_14223.jpg
#
# Source Key:		imgs/train/c0/img_14313.jpg
# Destination Key:	imgs/validation/c0/img_14313.jpg
#
# Source Key:		imgs/train/c0/img_14399.jpg
# Destination Key:	imgs/validation/c0/img_14399.jpg
#
# Source Key:		imgs/train/c0/img_14492.jpg
# Destination Key:	imgs/validation/c0/img_14492.jpg
#
# Source Key:		imgs/train/c0/img_14705.jpg
# Destination Key:	imgs/validation/c0/img_14705.jpg
#
# Source Key:		imgs/train/c0/img_1487.jpg
# Destination Key:	imgs/validation/c0/img_1487.jpg
#
# Source Key:		imgs/train/c0/img_14870.jpg
# Destination Key:	imgs/validation/c0/img_14870.jpg
#
# Source Key:		imgs/train/c0/img_14903.jpg
# Destination Key:	imgs/validation/c0/img_14903.jpg
#
# Source Key:		imgs/train/c0/img_14979.jpg
# Destination Key:	imgs/validation/c0/img_14979.jpg
#
# Source Key:		imgs/train/c0/img_15073.jpg
# Destination Key:	imgs/validation/c0/img_15073.jpg
#
# Source Key:		imgs/train/c0/img_1519.jpg
# Destination Key:	imgs/validation/c0/img_1519.jpg
#
# Source Key:		imgs/train/c0/img_15571.jpg
# Destination Key:	imgs/validation/c0/img_15571.jpg
#
# Source Key:		imgs/train/c0/img_15760.jpg
# Destination Key:	imgs/validation/c0/img_15760.jpg
#
# Source Key:		imgs/train/c0/img_15823.jpg
# Destination Key:	imgs/validation/c0/img_15823.jpg
#
# Source Key:		imgs/train/c0/img_15855.jpg
# Destination Key:	imgs/validation/c0/img_15855.jpg
#
# Source Key:		imgs/train/c0/img_15882.jpg
# Destination Key:	imgs/validation/c0/img_15882.jpg
#
# Source Key:		imgs/train/c0/img_16035.jpg
# Destination Key:	imgs/validation/c0/img_16035.jpg
#
# Source Key:		imgs/train/c0/img_16345.jpg
# Destination Key:	imgs/validation/c0/img_16345.jpg
#
# Source Key:		imgs/train/c0/img_16355.jpg
# Destination Key:	imgs/validation/c0/img_16355.jpg
#
# Source Key:		imgs/train/c0/img_16474.jpg
# Destination Key:	imgs/validation/c0/img_16474.jpg
#
# Source Key:		imgs/train/c0/img_16486.jpg
# Destination Key:	imgs/validation/c0/img_16486.jpg
#
# Source Key:		imgs/train/c0/img_16575.jpg
# Destination Key:	imgs/validation/c0/img_16575.jpg
#
# Source Key:		imgs/train/c0/img_17066.jpg
# Destination Key:	imgs/validation/c0/img_17066.jpg
#
# Source Key:		imgs/train/c0/img_17470.jpg
# Destination Key:	imgs/validation/c0/img_17470.jpg
#
# Source Key:		imgs/train/c0/img_17515.jpg
# Destination Key:	imgs/validation/c0/img_17515.jpg
#
# Source Key:		imgs/train/c0/img_17524.jpg
# Destination Key:	imgs/validation/c0/img_17524.jpg
#
# Source Key:		imgs/train/c0/img_17723.jpg
# Destination Key:	imgs/validation/c0/img_17723.jpg
#
# Source Key:		imgs/train/c0/img_17736.jpg
# Destination Key:	imgs/validation/c0/img_17736.jpg
#
# Source Key:		imgs/train/c0/img_18138.jpg
# Destination Key:	imgs/validation/c0/img_18138.jpg
#
# Source Key:		imgs/train/c0/img_18225.jpg
# Destination Key:	imgs/validation/c0/img_18225.jpg
#
# Source Key:		imgs/train/c0/img_18391.jpg
# Destination Key:	imgs/validation/c0/img_18391.jpg
#
# Source Key:		imgs/train/c0/img_18409.jpg
# Destination Key:	imgs/validation/c0/img_18409.jpg
#
# Source Key:		imgs/train/c0/img_18738.jpg
# Destination Key:	imgs/validation/c0/img_18738.jpg
#
# Source Key:		imgs/train/c0/img_18799.jpg
# Destination Key:	imgs/validation/c0/img_18799.jpg
#
# Source Key:		imgs/train/c0/img_18940.jpg
# Destination Key:	imgs/validation/c0/img_18940.jpg
#
# Source Key:		imgs/train/c0/img_19098.jpg
# Destination Key:	imgs/validation/c0/img_19098.jpg
#
# Source Key:		imgs/train/c0/img_1929.jpg
# Destination Key:	imgs/validation/c0/img_1929.jpg
#
# Source Key:		imgs/train/c0/img_19303.jpg
# Destination Key:	imgs/validation/c0/img_19303.jpg
#
# Source Key:		imgs/train/c0/img_19386.jpg
# Destination Key:	imgs/validation/c0/img_19386.jpg
#
# Source Key:		imgs/train/c0/img_1942.jpg
# Destination Key:	imgs/validation/c0/img_1942.jpg
#
# Source Key:		imgs/train/c0/img_19691.jpg
# Destination Key:	imgs/validation/c0/img_19691.jpg
#
# Source Key:		imgs/train/c0/img_20192.jpg
# Destination Key:	imgs/validation/c0/img_20192.jpg
#
# Source Key:		imgs/train/c0/img_20350.jpg
# Destination Key:	imgs/validation/c0/img_20350.jpg
#
# Source Key:		imgs/train/c0/img_20588.jpg
# Destination Key:	imgs/validation/c0/img_20588.jpg
#
# Source Key:		imgs/train/c0/img_20878.jpg
# Destination Key:	imgs/validation/c0/img_20878.jpg
#
# Source Key:		imgs/train/c0/img_2093.jpg
# Destination Key:	imgs/validation/c0/img_2093.jpg
#
# Source Key:		imgs/train/c0/img_20966.jpg
# Destination Key:	imgs/validation/c0/img_20966.jpg
#
# Source Key:		imgs/train/c0/img_21731.jpg
# Destination Key:	imgs/validation/c0/img_21731.jpg
#
# Source Key:		imgs/train/c0/img_21733.jpg
# Destination Key:	imgs/validation/c0/img_21733.jpg
#
# Source Key:		imgs/train/c0/img_21767.jpg
# Destination Key:	imgs/validation/c0/img_21767.jpg
#
# Source Key:		imgs/train/c0/img_21782.jpg
# Destination Key:	imgs/validation/c0/img_21782.jpg
#
# Source Key:		imgs/train/c0/img_2191.jpg
# Destination Key:	imgs/validation/c0/img_2191.jpg
#
# Source Key:		imgs/train/c0/img_22029.jpg
# Destination Key:	imgs/validation/c0/img_22029.jpg
#
# Source Key:		imgs/train/c0/img_2236.jpg
# Destination Key:	imgs/validation/c0/img_2236.jpg
#
# Source Key:		imgs/train/c0/img_22750.jpg
# Destination Key:	imgs/validation/c0/img_22750.jpg
#
# Source Key:		imgs/train/c0/img_22820.jpg
# Destination Key:	imgs/validation/c0/img_22820.jpg
#
# Source Key:		imgs/train/c0/img_23082.jpg
# Destination Key:	imgs/validation/c0/img_23082.jpg
#
# Source Key:		imgs/train/c0/img_23144.jpg
# Destination Key:	imgs/validation/c0/img_23144.jpg
#
# Source Key:		imgs/train/c0/img_23158.jpg
# Destination Key:	imgs/validation/c0/img_23158.jpg
#
# Source Key:		imgs/train/c0/img_23196.jpg
# Destination Key:	imgs/validation/c0/img_23196.jpg
#
# Source Key:		imgs/train/c0/img_23231.jpg
# Destination Key:	imgs/validation/c0/img_23231.jpg
#
# Source Key:		imgs/train/c0/img_23449.jpg
# Destination Key:	imgs/validation/c0/img_23449.jpg
#
# Source Key:		imgs/train/c0/img_2380.jpg
# Destination Key:	imgs/validation/c0/img_2380.jpg
#
# Source Key:		imgs/train/c0/img_23910.jpg
# Destination Key:	imgs/validation/c0/img_23910.jpg
#
# Source Key:		imgs/train/c0/img_24139.jpg
# Destination Key:	imgs/validation/c0/img_24139.jpg
#
# Source Key:		imgs/train/c0/img_24190.jpg
# Destination Key:	imgs/validation/c0/img_24190.jpg
#
# Source Key:		imgs/train/c0/img_24204.jpg
# Destination Key:	imgs/validation/c0/img_24204.jpg
#
# Source Key:		imgs/train/c0/img_24232.jpg
# Destination Key:	imgs/validation/c0/img_24232.jpg
#
# Source Key:		imgs/train/c0/img_24234.jpg
# Destination Key:	imgs/validation/c0/img_24234.jpg
#
# Source Key:		imgs/train/c0/img_24403.jpg
# Destination Key:	imgs/validation/c0/img_24403.jpg
#
# Source Key:		imgs/train/c0/img_24419.jpg
# Destination Key:	imgs/validation/c0/img_24419.jpg
#
# Source Key:		imgs/train/c0/img_24493.jpg
# Destination Key:	imgs/validation/c0/img_24493.jpg
#
# Source Key:		imgs/train/c0/img_24706.jpg
# Destination Key:	imgs/validation/c0/img_24706.jpg
#
# Source Key:		imgs/train/c0/img_24750.jpg
# Destination Key:	imgs/validation/c0/img_24750.jpg
#
# Source Key:		imgs/train/c0/img_24771.jpg
# Destination Key:	imgs/validation/c0/img_24771.jpg
#
# Source Key:		imgs/train/c0/img_25298.jpg
# Destination Key:	imgs/validation/c0/img_25298.jpg
#
# Source Key:		imgs/train/c0/img_2545.jpg
# Destination Key:	imgs/validation/c0/img_2545.jpg
#
# Source Key:		imgs/train/c0/img_25778.jpg
# Destination Key:	imgs/validation/c0/img_25778.jpg
#
# Source Key:		imgs/train/c0/img_26025.jpg
# Destination Key:	imgs/validation/c0/img_26025.jpg
#
# Source Key:		imgs/train/c0/img_26089.jpg
# Destination Key:	imgs/validation/c0/img_26089.jpg
#
# Source Key:		imgs/train/c0/img_26166.jpg
# Destination Key:	imgs/validation/c0/img_26166.jpg
#
# Source Key:		imgs/train/c0/img_26342.jpg
# Destination Key:	imgs/validation/c0/img_26342.jpg
#
# Source Key:		imgs/train/c0/img_26370.jpg
# Destination Key:	imgs/validation/c0/img_26370.jpg
#
# Source Key:		imgs/train/c0/img_26502.jpg
# Destination Key:	imgs/validation/c0/img_26502.jpg
#
# Source Key:		imgs/train/c0/img_26907.jpg
# Destination Key:	imgs/validation/c0/img_26907.jpg
#
# Source Key:		imgs/train/c0/img_27005.jpg
# Destination Key:	imgs/validation/c0/img_27005.jpg
#
# Source Key:		imgs/train/c0/img_2704.jpg
# Destination Key:	imgs/validation/c0/img_2704.jpg
#
# Source Key:		imgs/train/c0/img_27079.jpg
# Destination Key:	imgs/validation/c0/img_27079.jpg
#
# Source Key:		imgs/train/c0/img_27134.jpg
# Destination Key:	imgs/validation/c0/img_27134.jpg
#
# Source Key:		imgs/train/c0/img_27214.jpg
# Destination Key:	imgs/validation/c0/img_27214.jpg
#
# Source Key:		imgs/train/c0/img_27282.jpg
# Destination Key:	imgs/validation/c0/img_27282.jpg
#
# Source Key:		imgs/train/c0/img_27480.jpg
# Destination Key:	imgs/validation/c0/img_27480.jpg
#
# Source Key:		imgs/train/c0/img_2765.jpg
# Destination Key:	imgs/validation/c0/img_2765.jpg
#
# Source Key:		imgs/train/c0/img_27877.jpg
# Destination Key:	imgs/validation/c0/img_27877.jpg
#
# Source Key:		imgs/train/c0/img_2805.jpg
# Destination Key:	imgs/validation/c0/img_2805.jpg
#
# Source Key:		imgs/train/c0/img_28115.jpg
# Destination Key:	imgs/validation/c0/img_28115.jpg
#
# Source Key:		imgs/train/c0/img_2813.jpg
# Destination Key:	imgs/validation/c0/img_2813.jpg
#
# Source Key:		imgs/train/c0/img_28357.jpg
# Destination Key:	imgs/validation/c0/img_28357.jpg
#
# Source Key:		imgs/train/c0/img_28465.jpg
# Destination Key:	imgs/validation/c0/img_28465.jpg
#
# Source Key:		imgs/train/c0/img_28569.jpg
# Destination Key:	imgs/validation/c0/img_28569.jpg
#
# Source Key:		imgs/train/c0/img_28666.jpg
# Destination Key:	imgs/validation/c0/img_28666.jpg
#
# Source Key:		imgs/train/c0/img_29005.jpg
# Destination Key:	imgs/validation/c0/img_29005.jpg
#
# Source Key:		imgs/train/c0/img_292.jpg
# Destination Key:	imgs/validation/c0/img_292.jpg
#
# Source Key:		imgs/train/c0/img_29332.jpg
# Destination Key:	imgs/validation/c0/img_29332.jpg
#
# Source Key:		imgs/train/c0/img_29340.jpg
# Destination Key:	imgs/validation/c0/img_29340.jpg
#
# Source Key:		imgs/train/c0/img_29348.jpg
# Destination Key:	imgs/validation/c0/img_29348.jpg
#
# Source Key:		imgs/train/c0/img_29863.jpg
# Destination Key:	imgs/validation/c0/img_29863.jpg
#
# Source Key:		imgs/train/c0/img_29868.jpg
# Destination Key:	imgs/validation/c0/img_29868.jpg
#
# Source Key:		imgs/train/c0/img_29877.jpg
# Destination Key:	imgs/validation/c0/img_29877.jpg
#
# Source Key:		imgs/train/c0/img_2992.jpg
# Destination Key:	imgs/validation/c0/img_2992.jpg
#
# Source Key:		imgs/train/c0/img_30060.jpg
# Destination Key:	imgs/validation/c0/img_30060.jpg
#
# Source Key:		imgs/train/c0/img_30164.jpg
# Destination Key:	imgs/validation/c0/img_30164.jpg
#
# Source Key:		imgs/train/c0/img_30340.jpg
# Destination Key:	imgs/validation/c0/img_30340.jpg
#
# Source Key:		imgs/train/c0/img_30520.jpg
# Destination Key:	imgs/validation/c0/img_30520.jpg
#
# Source Key:		imgs/train/c0/img_31068.jpg
# Destination Key:	imgs/validation/c0/img_31068.jpg
#
# Source Key:		imgs/train/c0/img_31094.jpg
# Destination Key:	imgs/validation/c0/img_31094.jpg
#
# Source Key:		imgs/train/c0/img_31251.jpg
# Destination Key:	imgs/validation/c0/img_31251.jpg
#
# Source Key:		imgs/train/c0/img_31289.jpg
# Destination Key:	imgs/validation/c0/img_31289.jpg
#
# Source Key:		imgs/train/c0/img_31345.jpg
# Destination Key:	imgs/validation/c0/img_31345.jpg
#
# Source Key:		imgs/train/c0/img_31355.jpg
# Destination Key:	imgs/validation/c0/img_31355.jpg
#
# Source Key:		imgs/train/c0/img_316.jpg
# Destination Key:	imgs/validation/c0/img_316.jpg
#
# Source Key:		imgs/train/c0/img_31613.jpg
# Destination Key:	imgs/validation/c0/img_31613.jpg
#
# Source Key:		imgs/train/c0/img_31623.jpg
# Destination Key:	imgs/validation/c0/img_31623.jpg
#
# Source Key:		imgs/train/c0/img_31785.jpg
# Destination Key:	imgs/validation/c0/img_31785.jpg
#
# Source Key:		imgs/train/c0/img_31857.jpg
# Destination Key:	imgs/validation/c0/img_31857.jpg
#
# Source Key:		imgs/train/c0/img_31885.jpg
# Destination Key:	imgs/validation/c0/img_31885.jpg
#
# Source Key:		imgs/train/c0/img_31997.jpg
# Destination Key:	imgs/validation/c0/img_31997.jpg
#
# Source Key:		imgs/train/c0/img_32074.jpg
# Destination Key:	imgs/validation/c0/img_32074.jpg
#
# Source Key:		imgs/train/c0/img_32153.jpg
# Destination Key:	imgs/validation/c0/img_32153.jpg
#
# Source Key:		imgs/train/c0/img_32257.jpg
# Destination Key:	imgs/validation/c0/img_32257.jpg
#
# Source Key:		imgs/train/c0/img_32321.jpg
# Destination Key:	imgs/validation/c0/img_32321.jpg
#
# Source Key:		imgs/train/c0/img_32486.jpg
# Destination Key:	imgs/validation/c0/img_32486.jpg
#
# Source Key:		imgs/train/c0/img_32619.jpg
# Destination Key:	imgs/validation/c0/img_32619.jpg
#
# Source Key:		imgs/train/c0/img_32810.jpg
# Destination Key:	imgs/validation/c0/img_32810.jpg
#
# Source Key:		imgs/train/c0/img_32825.jpg
# Destination Key:	imgs/validation/c0/img_32825.jpg
#
# Source Key:		imgs/train/c0/img_32994.jpg
# Destination Key:	imgs/validation/c0/img_32994.jpg
#
# Source Key:		imgs/train/c0/img_33097.jpg
# Destination Key:	imgs/validation/c0/img_33097.jpg
#
# Source Key:		imgs/train/c0/img_33238.jpg
# Destination Key:	imgs/validation/c0/img_33238.jpg
#
# Source Key:		imgs/train/c0/img_33315.jpg
# Destination Key:	imgs/validation/c0/img_33315.jpg
#
# Source Key:		imgs/train/c0/img_33475.jpg
# Destination Key:	imgs/validation/c0/img_33475.jpg
#
# Source Key:		imgs/train/c0/img_33484.jpg
# Destination Key:	imgs/validation/c0/img_33484.jpg
#
# Source Key:		imgs/train/c0/img_33727.jpg
# Destination Key:	imgs/validation/c0/img_33727.jpg
#
# Source Key:		imgs/train/c0/img_33768.jpg
# Destination Key:	imgs/validation/c0/img_33768.jpg
#
# Source Key:		imgs/train/c0/img_33800.jpg
# Destination Key:	imgs/validation/c0/img_33800.jpg
#
# Source Key:		imgs/train/c0/img_34.jpg
# Destination Key:	imgs/validation/c0/img_34.jpg
#
# Source Key:		imgs/train/c0/img_34028.jpg
# Destination Key:	imgs/validation/c0/img_34028.jpg
#
# Source Key:		imgs/train/c0/img_34224.jpg
# Destination Key:	imgs/validation/c0/img_34224.jpg
#
# Source Key:		imgs/train/c0/img_34269.jpg
# Destination Key:	imgs/validation/c0/img_34269.jpg
#
# Source Key:		imgs/train/c0/img_3432.jpg
# Destination Key:	imgs/validation/c0/img_3432.jpg
#
# Source Key:		imgs/train/c0/img_344.jpg
# Destination Key:	imgs/validation/c0/img_344.jpg
#
# Source Key:		imgs/train/c0/img_34435.jpg
# Destination Key:	imgs/validation/c0/img_34435.jpg
#
# Source Key:		imgs/train/c0/img_34518.jpg
# Destination Key:	imgs/validation/c0/img_34518.jpg
#
# Source Key:		imgs/train/c0/img_35203.jpg
# Destination Key:	imgs/validation/c0/img_35203.jpg
#
# Source Key:		imgs/train/c0/img_35231.jpg
# Destination Key:	imgs/validation/c0/img_35231.jpg
#
# Source Key:		imgs/train/c0/img_35290.jpg
# Destination Key:	imgs/validation/c0/img_35290.jpg
#
# Source Key:		imgs/train/c0/img_35369.jpg
# Destination Key:	imgs/validation/c0/img_35369.jpg
#
# Source Key:		imgs/train/c0/img_35525.jpg
# Destination Key:	imgs/validation/c0/img_35525.jpg
#
# Source Key:		imgs/train/c0/img_35669.jpg
# Destination Key:	imgs/validation/c0/img_35669.jpg
#
# Source Key:		imgs/train/c0/img_35878.jpg
# Destination Key:	imgs/validation/c0/img_35878.jpg
#
# Source Key:		imgs/train/c0/img_36173.jpg
# Destination Key:	imgs/validation/c0/img_36173.jpg
#
# Source Key:		imgs/train/c0/img_36206.jpg
# Destination Key:	imgs/validation/c0/img_36206.jpg
#
# Source Key:		imgs/train/c0/img_36300.jpg
# Destination Key:	imgs/validation/c0/img_36300.jpg
#
# Source Key:		imgs/train/c0/img_36330.jpg
# Destination Key:	imgs/validation/c0/img_36330.jpg
#
# Source Key:		imgs/train/c0/img_36354.jpg
# Destination Key:	imgs/validation/c0/img_36354.jpg
#
# Source Key:		imgs/train/c0/img_36370.jpg
# Destination Key:	imgs/validation/c0/img_36370.jpg
#
# Source Key:		imgs/train/c0/img_3655.jpg
# Destination Key:	imgs/validation/c0/img_3655.jpg
#
# Source Key:		imgs/train/c0/img_36574.jpg
# Destination Key:	imgs/validation/c0/img_36574.jpg
#
# Source Key:		imgs/train/c0/img_36597.jpg
# Destination Key:	imgs/validation/c0/img_36597.jpg
#
# Source Key:		imgs/train/c0/img_36910.jpg
# Destination Key:	imgs/validation/c0/img_36910.jpg
#
# Source Key:		imgs/train/c0/img_36943.jpg
# Destination Key:	imgs/validation/c0/img_36943.jpg
#
# Source Key:		imgs/train/c0/img_36959.jpg
# Destination Key:	imgs/validation/c0/img_36959.jpg
#
# Source Key:		imgs/train/c0/img_37200.jpg
# Destination Key:	imgs/validation/c0/img_37200.jpg
#
# Source Key:		imgs/train/c0/img_37234.jpg
# Destination Key:	imgs/validation/c0/img_37234.jpg
#
# Source Key:		imgs/train/c0/img_3726.jpg
# Destination Key:	imgs/validation/c0/img_3726.jpg
#
# Source Key:		imgs/train/c0/img_37288.jpg
# Destination Key:	imgs/validation/c0/img_37288.jpg
#
# Source Key:		imgs/train/c0/img_3739.jpg
# Destination Key:	imgs/validation/c0/img_3739.jpg
#
# Source Key:		imgs/train/c0/img_37741.jpg
# Destination Key:	imgs/validation/c0/img_37741.jpg
#
# Source Key:		imgs/train/c0/img_38088.jpg
# Destination Key:	imgs/validation/c0/img_38088.jpg
#
# Source Key:		imgs/train/c0/img_38321.jpg
# Destination Key:	imgs/validation/c0/img_38321.jpg
#
# Source Key:		imgs/train/c0/img_38377.jpg
# Destination Key:	imgs/validation/c0/img_38377.jpg
#
# Source Key:		imgs/train/c0/img_38469.jpg
# Destination Key:	imgs/validation/c0/img_38469.jpg
#
# Source Key:		imgs/train/c0/img_38502.jpg
# Destination Key:	imgs/validation/c0/img_38502.jpg
#
# Source Key:		imgs/train/c0/img_38514.jpg
# Destination Key:	imgs/validation/c0/img_38514.jpg
#
# Source Key:		imgs/train/c0/img_3866.jpg
# Destination Key:	imgs/validation/c0/img_3866.jpg
#
# Source Key:		imgs/train/c0/img_38722.jpg
# Destination Key:	imgs/validation/c0/img_38722.jpg
#
# Source Key:		imgs/train/c0/img_38766.jpg
# Destination Key:	imgs/validation/c0/img_38766.jpg
#
# Source Key:		imgs/train/c0/img_38843.jpg
# Destination Key:	imgs/validation/c0/img_38843.jpg
#
# Source Key:		imgs/train/c0/img_39126.jpg
# Destination Key:	imgs/validation/c0/img_39126.jpg
#
# Source Key:		imgs/train/c0/img_39359.jpg
# Destination Key:	imgs/validation/c0/img_39359.jpg
#
# Source Key:		imgs/train/c0/img_3939.jpg
# Destination Key:	imgs/validation/c0/img_3939.jpg
#
# Source Key:		imgs/train/c0/img_39447.jpg
# Destination Key:	imgs/validation/c0/img_39447.jpg
#
# Source Key:		imgs/train/c0/img_39681.jpg
# Destination Key:	imgs/validation/c0/img_39681.jpg
#
# Source Key:		imgs/train/c0/img_39682.jpg
# Destination Key:	imgs/validation/c0/img_39682.jpg
#
# Source Key:		imgs/train/c0/img_39839.jpg
# Destination Key:	imgs/validation/c0/img_39839.jpg
#
# Source Key:		imgs/train/c0/img_39956.jpg
# Destination Key:	imgs/validation/c0/img_39956.jpg
#
# Source Key:		imgs/train/c0/img_40020.jpg
# Destination Key:	imgs/validation/c0/img_40020.jpg
#
# Source Key:		imgs/train/c0/img_40038.jpg
# Destination Key:	imgs/validation/c0/img_40038.jpg
#
# Source Key:		imgs/train/c0/img_40209.jpg
# Destination Key:	imgs/validation/c0/img_40209.jpg
#
# Source Key:		imgs/train/c0/img_40312.jpg
# Destination Key:	imgs/validation/c0/img_40312.jpg
#
# Source Key:		imgs/train/c0/img_40349.jpg
# Destination Key:	imgs/validation/c0/img_40349.jpg
#
# Source Key:		imgs/train/c0/img_40374.jpg
# Destination Key:	imgs/validation/c0/img_40374.jpg
#
# Source Key:		imgs/train/c0/img_40742.jpg
# Destination Key:	imgs/validation/c0/img_40742.jpg
#
# Source Key:		imgs/train/c0/img_40865.jpg
# Destination Key:	imgs/validation/c0/img_40865.jpg
#
# Source Key:		imgs/train/c0/img_41128.jpg
# Destination Key:	imgs/validation/c0/img_41128.jpg
#
# Source Key:		imgs/train/c0/img_41282.jpg
# Destination Key:	imgs/validation/c0/img_41282.jpg
#
# Source Key:		imgs/train/c0/img_41348.jpg
# Destination Key:	imgs/validation/c0/img_41348.jpg
#
# Source Key:		imgs/train/c0/img_41423.jpg
# Destination Key:	imgs/validation/c0/img_41423.jpg
#
# Source Key:		imgs/train/c0/img_41813.jpg
# Destination Key:	imgs/validation/c0/img_41813.jpg
#
# Source Key:		imgs/train/c0/img_41847.jpg
# Destination Key:	imgs/validation/c0/img_41847.jpg
#
# Source Key:		imgs/train/c0/img_41911.jpg
# Destination Key:	imgs/validation/c0/img_41911.jpg
#
# Source Key:		imgs/train/c0/img_41958.jpg
# Destination Key:	imgs/validation/c0/img_41958.jpg
#
# Source Key:		imgs/train/c0/img_42144.jpg
# Destination Key:	imgs/validation/c0/img_42144.jpg
#
# Source Key:		imgs/train/c0/img_42336.jpg
# Destination Key:	imgs/validation/c0/img_42336.jpg
#
# Source Key:		imgs/train/c0/img_42587.jpg
# Destination Key:	imgs/validation/c0/img_42587.jpg
#
# Source Key:		imgs/train/c0/img_42643.jpg
# Destination Key:	imgs/validation/c0/img_42643.jpg
#
# Source Key:		imgs/train/c0/img_42723.jpg
# Destination Key:	imgs/validation/c0/img_42723.jpg
#
# Source Key:		imgs/train/c0/img_42766.jpg
# Destination Key:	imgs/validation/c0/img_42766.jpg
#
# Source Key:		imgs/train/c0/img_42832.jpg
# Destination Key:	imgs/validation/c0/img_42832.jpg
#
# Source Key:		imgs/train/c0/img_42975.jpg
# Destination Key:	imgs/validation/c0/img_42975.jpg
#
# Source Key:		imgs/train/c0/img_4362.jpg
# Destination Key:	imgs/validation/c0/img_4362.jpg
#
# Source Key:		imgs/train/c0/img_43734.jpg
# Destination Key:	imgs/validation/c0/img_43734.jpg
#
# Source Key:		imgs/train/c0/img_43775.jpg
# Destination Key:	imgs/validation/c0/img_43775.jpg
#
# Source Key:		imgs/train/c0/img_43848.jpg
# Destination Key:	imgs/validation/c0/img_43848.jpg
#
# Source Key:		imgs/train/c0/img_4399.jpg
# Destination Key:	imgs/validation/c0/img_4399.jpg
#
# Source Key:		imgs/train/c0/img_44073.jpg
# Destination Key:	imgs/validation/c0/img_44073.jpg
#
# Source Key:		imgs/train/c0/img_44419.jpg
# Destination Key:	imgs/validation/c0/img_44419.jpg
#
# Source Key:		imgs/train/c0/img_44422.jpg
# Destination Key:	imgs/validation/c0/img_44422.jpg
#
# Source Key:		imgs/train/c0/img_44655.jpg
# Destination Key:	imgs/validation/c0/img_44655.jpg
#
# Source Key:		imgs/train/c0/img_44686.jpg
# Destination Key:	imgs/validation/c0/img_44686.jpg
#
# Source Key:		imgs/train/c0/img_44820.jpg
# Destination Key:	imgs/validation/c0/img_44820.jpg
#
# Source Key:		imgs/train/c0/img_44933.jpg
# Destination Key:	imgs/validation/c0/img_44933.jpg
#
# Source Key:		imgs/train/c0/img_45462.jpg
# Destination Key:	imgs/validation/c0/img_45462.jpg
#
# Source Key:		imgs/train/c0/img_45554.jpg
# Destination Key:	imgs/validation/c0/img_45554.jpg
#
# Source Key:		imgs/train/c0/img_45671.jpg
# Destination Key:	imgs/validation/c0/img_45671.jpg
#
# Source Key:		imgs/train/c0/img_45980.jpg
# Destination Key:	imgs/validation/c0/img_45980.jpg
#
# Source Key:		imgs/train/c0/img_46034.jpg
# Destination Key:	imgs/validation/c0/img_46034.jpg
#
# Source Key:		imgs/train/c0/img_46053.jpg
# Destination Key:	imgs/validation/c0/img_46053.jpg
#
# Source Key:		imgs/train/c0/img_46060.jpg
# Destination Key:	imgs/validation/c0/img_46060.jpg
#
# Source Key:		imgs/train/c0/img_46105.jpg
# Destination Key:	imgs/validation/c0/img_46105.jpg
#
# Source Key:		imgs/train/c0/img_4629.jpg
# Destination Key:	imgs/validation/c0/img_4629.jpg
#
# Source Key:		imgs/train/c0/img_46484.jpg
# Destination Key:	imgs/validation/c0/img_46484.jpg
#
# Source Key:		imgs/train/c0/img_46818.jpg
# Destination Key:	imgs/validation/c0/img_46818.jpg
#
# Source Key:		imgs/train/c0/img_46834.jpg
# Destination Key:	imgs/validation/c0/img_46834.jpg
#
# Source Key:		imgs/train/c0/img_47131.jpg
# Destination Key:	imgs/validation/c0/img_47131.jpg
#
# Source Key:		imgs/train/c0/img_47216.jpg
# Destination Key:	imgs/validation/c0/img_47216.jpg
#
# Source Key:		imgs/train/c0/img_47285.jpg
# Destination Key:	imgs/validation/c0/img_47285.jpg
#
# Source Key:		imgs/train/c0/img_47332.jpg
# Destination Key:	imgs/validation/c0/img_47332.jpg
#
# Source Key:		imgs/train/c0/img_47410.jpg
# Destination Key:	imgs/validation/c0/img_47410.jpg
#
# Source Key:		imgs/train/c0/img_47528.jpg
# Destination Key:	imgs/validation/c0/img_47528.jpg
#
# Source Key:		imgs/train/c0/img_47634.jpg
# Destination Key:	imgs/validation/c0/img_47634.jpg
#
# Source Key:		imgs/train/c0/img_47700.jpg
# Destination Key:	imgs/validation/c0/img_47700.jpg
#
# Source Key:		imgs/train/c0/img_47956.jpg
# Destination Key:	imgs/validation/c0/img_47956.jpg
#
# Source Key:		imgs/train/c0/img_48161.jpg
# Destination Key:	imgs/validation/c0/img_48161.jpg
#
# Source Key:		imgs/train/c0/img_48334.jpg
# Destination Key:	imgs/validation/c0/img_48334.jpg
#
# Source Key:		imgs/train/c0/img_48882.jpg
# Destination Key:	imgs/validation/c0/img_48882.jpg
#
# Source Key:		imgs/train/c0/img_4891.jpg
# Destination Key:	imgs/validation/c0/img_4891.jpg
#
# Source Key:		imgs/train/c0/img_49215.jpg
# Destination Key:	imgs/validation/c0/img_49215.jpg
#
# Source Key:		imgs/train/c0/img_49423.jpg
# Destination Key:	imgs/validation/c0/img_49423.jpg
#
# Source Key:		imgs/train/c0/img_49775.jpg
# Destination Key:	imgs/validation/c0/img_49775.jpg
#
# Source Key:		imgs/train/c0/img_49809.jpg
# Destination Key:	imgs/validation/c0/img_49809.jpg
#
# Source Key:		imgs/train/c0/img_49851.jpg
# Destination Key:	imgs/validation/c0/img_49851.jpg
#
# Source Key:		imgs/train/c0/img_49872.jpg
# Destination Key:	imgs/validation/c0/img_49872.jpg
#
# Source Key:		imgs/train/c0/img_50007.jpg
# Destination Key:	imgs/validation/c0/img_50007.jpg
#
# Source Key:		imgs/train/c0/img_50246.jpg
# Destination Key:	imgs/validation/c0/img_50246.jpg
#
# Source Key:		imgs/train/c0/img_50295.jpg
# Destination Key:	imgs/validation/c0/img_50295.jpg
#
# Source Key:		imgs/train/c0/img_50371.jpg
# Destination Key:	imgs/validation/c0/img_50371.jpg
#
# Source Key:		imgs/train/c0/img_50384.jpg
# Destination Key:	imgs/validation/c0/img_50384.jpg
#
# Source Key:		imgs/train/c0/img_50477.jpg
# Destination Key:	imgs/validation/c0/img_50477.jpg
#
# Source Key:		imgs/train/c0/img_50553.jpg
# Destination Key:	imgs/validation/c0/img_50553.jpg
#
# Source Key:		imgs/train/c0/img_50577.jpg
# Destination Key:	imgs/validation/c0/img_50577.jpg
#
# Source Key:		imgs/train/c0/img_50702.jpg
# Destination Key:	imgs/validation/c0/img_50702.jpg
#
# Source Key:		imgs/train/c0/img_50749.jpg
# Destination Key:	imgs/validation/c0/img_50749.jpg
#
# Source Key:		imgs/train/c0/img_50792.jpg
# Destination Key:	imgs/validation/c0/img_50792.jpg
#
# Source Key:		imgs/train/c0/img_50819.jpg
# Destination Key:	imgs/validation/c0/img_50819.jpg
#
# Source Key:		imgs/train/c0/img_51078.jpg
# Destination Key:	imgs/validation/c0/img_51078.jpg
#
# Source Key:		imgs/train/c0/img_51658.jpg
# Destination Key:	imgs/validation/c0/img_51658.jpg
#
# Source Key:		imgs/train/c0/img_51729.jpg
# Destination Key:	imgs/validation/c0/img_51729.jpg
#
# Source Key:		imgs/train/c0/img_51935.jpg
# Destination Key:	imgs/validation/c0/img_51935.jpg
#
# Source Key:		imgs/train/c0/img_52282.jpg
# Destination Key:	imgs/validation/c0/img_52282.jpg
#
# Source Key:		imgs/train/c0/img_5232.jpg
# Destination Key:	imgs/validation/c0/img_5232.jpg
#
# Source Key:		imgs/train/c0/img_52460.jpg
# Destination Key:	imgs/validation/c0/img_52460.jpg
#
# Source Key:		imgs/train/c0/img_52476.jpg
# Destination Key:	imgs/validation/c0/img_52476.jpg
#
# Source Key:		imgs/train/c0/img_52557.jpg
# Destination Key:	imgs/validation/c0/img_52557.jpg
#
# Source Key:		imgs/train/c0/img_52570.jpg
# Destination Key:	imgs/validation/c0/img_52570.jpg
#
# Source Key:		imgs/train/c0/img_52670.jpg
# Destination Key:	imgs/validation/c0/img_52670.jpg
#
# Source Key:		imgs/train/c0/img_52801.jpg
# Destination Key:	imgs/validation/c0/img_52801.jpg
#
# Source Key:		imgs/train/c0/img_53025.jpg
# Destination Key:	imgs/validation/c0/img_53025.jpg
#
# Source Key:		imgs/train/c0/img_53053.jpg
# Destination Key:	imgs/validation/c0/img_53053.jpg
#
# Source Key:		imgs/train/c0/img_53148.jpg
# Destination Key:	imgs/validation/c0/img_53148.jpg
#
# Source Key:		imgs/train/c0/img_5324.jpg
# Destination Key:	imgs/validation/c0/img_5324.jpg
#
# Source Key:		imgs/train/c0/img_5329.jpg
# Destination Key:	imgs/validation/c0/img_5329.jpg
#
# Source Key:		imgs/train/c0/img_5342.jpg
# Destination Key:	imgs/validation/c0/img_5342.jpg
#
# Source Key:		imgs/train/c0/img_5349.jpg
# Destination Key:	imgs/validation/c0/img_5349.jpg
#
# Source Key:		imgs/train/c0/img_53526.jpg
# Destination Key:	imgs/validation/c0/img_53526.jpg
#
# Source Key:		imgs/train/c0/img_53692.jpg
# Destination Key:	imgs/validation/c0/img_53692.jpg
#
# Source Key:		imgs/train/c0/img_53698.jpg
# Destination Key:	imgs/validation/c0/img_53698.jpg
#
# Source Key:		imgs/train/c0/img_53945.jpg
# Destination Key:	imgs/validation/c0/img_53945.jpg
#
# Source Key:		imgs/train/c0/img_54109.jpg
# Destination Key:	imgs/validation/c0/img_54109.jpg
#
# Source Key:		imgs/train/c0/img_54170.jpg
# Destination Key:	imgs/validation/c0/img_54170.jpg
#
# Source Key:		imgs/train/c0/img_54393.jpg
# Destination Key:	imgs/validation/c0/img_54393.jpg
#
# Source Key:		imgs/train/c0/img_5449.jpg
# Destination Key:	imgs/validation/c0/img_5449.jpg
#
# Source Key:		imgs/train/c0/img_54531.jpg
# Destination Key:	imgs/validation/c0/img_54531.jpg
#
# Source Key:		imgs/train/c0/img_54533.jpg
# Destination Key:	imgs/validation/c0/img_54533.jpg
#
# Source Key:		imgs/train/c0/img_54792.jpg
# Destination Key:	imgs/validation/c0/img_54792.jpg
#
# Source Key:		imgs/train/c0/img_54849.jpg
# Destination Key:	imgs/validation/c0/img_54849.jpg
#
# Source Key:		imgs/train/c0/img_54857.jpg
# Destination Key:	imgs/validation/c0/img_54857.jpg
#
# Source Key:		imgs/train/c0/img_54924.jpg
# Destination Key:	imgs/validation/c0/img_54924.jpg
#
# Source Key:		imgs/train/c0/img_54960.jpg
# Destination Key:	imgs/validation/c0/img_54960.jpg
#
# Source Key:		imgs/train/c0/img_55100.jpg
# Destination Key:	imgs/validation/c0/img_55100.jpg
#
# Source Key:		imgs/train/c0/img_5514.jpg
# Destination Key:	imgs/validation/c0/img_5514.jpg
#
# Source Key:		imgs/train/c0/img_55291.jpg
# Destination Key:	imgs/validation/c0/img_55291.jpg
#
# Source Key:		imgs/train/c0/img_55312.jpg
# Destination Key:	imgs/validation/c0/img_55312.jpg
#
# Source Key:		imgs/train/c0/img_55719.jpg
# Destination Key:	imgs/validation/c0/img_55719.jpg
#
# Source Key:		imgs/train/c0/img_55929.jpg
# Destination Key:	imgs/validation/c0/img_55929.jpg
#
# Source Key:		imgs/train/c0/img_55933.jpg
# Destination Key:	imgs/validation/c0/img_55933.jpg
#
# Source Key:		imgs/train/c0/img_5613.jpg
# Destination Key:	imgs/validation/c0/img_5613.jpg
#
# Source Key:		imgs/train/c0/img_56142.jpg
# Destination Key:	imgs/validation/c0/img_56142.jpg
#
# Source Key:		imgs/train/c0/img_56374.jpg
# Destination Key:	imgs/validation/c0/img_56374.jpg
#
# Source Key:		imgs/train/c0/img_56466.jpg
# Destination Key:	imgs/validation/c0/img_56466.jpg
#
# Source Key:		imgs/train/c0/img_56588.jpg
# Destination Key:	imgs/validation/c0/img_56588.jpg
#
# Source Key:		imgs/train/c0/img_56666.jpg
# Destination Key:	imgs/validation/c0/img_56666.jpg
#
# Source Key:		imgs/train/c0/img_56741.jpg
# Destination Key:	imgs/validation/c0/img_56741.jpg
#
# Source Key:		imgs/train/c0/img_56851.jpg
# Destination Key:	imgs/validation/c0/img_56851.jpg
#
# Source Key:		imgs/train/c0/img_56931.jpg
# Destination Key:	imgs/validation/c0/img_56931.jpg
#
# Source Key:		imgs/train/c0/img_56942.jpg
# Destination Key:	imgs/validation/c0/img_56942.jpg
#
# Source Key:		imgs/train/c0/img_57096.jpg
# Destination Key:	imgs/validation/c0/img_57096.jpg
#
# Source Key:		imgs/train/c0/img_57112.jpg
# Destination Key:	imgs/validation/c0/img_57112.jpg
#
# Source Key:		imgs/train/c0/img_5716.jpg
# Destination Key:	imgs/validation/c0/img_5716.jpg
#
# Source Key:		imgs/train/c0/img_57216.jpg
# Destination Key:	imgs/validation/c0/img_57216.jpg
#
# Source Key:		imgs/train/c0/img_57235.jpg
# Destination Key:	imgs/validation/c0/img_57235.jpg
#
# Source Key:		imgs/train/c0/img_57365.jpg
# Destination Key:	imgs/validation/c0/img_57365.jpg
#
# Source Key:		imgs/train/c0/img_57520.jpg
# Destination Key:	imgs/validation/c0/img_57520.jpg
#
# Source Key:		imgs/train/c0/img_57583.jpg
# Destination Key:	imgs/validation/c0/img_57583.jpg
#
# Source Key:		imgs/train/c0/img_57598.jpg
# Destination Key:	imgs/validation/c0/img_57598.jpg
#
# Source Key:		imgs/train/c0/img_57789.jpg
# Destination Key:	imgs/validation/c0/img_57789.jpg
#
# Source Key:		imgs/train/c0/img_58093.jpg
# Destination Key:	imgs/validation/c0/img_58093.jpg
#
# Source Key:		imgs/train/c0/img_58104.jpg
# Destination Key:	imgs/validation/c0/img_58104.jpg
#
# Source Key:		imgs/train/c0/img_58456.jpg
# Destination Key:	imgs/validation/c0/img_58456.jpg
#
# Source Key:		imgs/train/c0/img_5846.jpg
# Destination Key:	imgs/validation/c0/img_5846.jpg
#
# Source Key:		imgs/train/c0/img_58502.jpg
# Destination Key:	imgs/validation/c0/img_58502.jpg
#
# Source Key:		imgs/train/c0/img_58541.jpg
# Destination Key:	imgs/validation/c0/img_58541.jpg
#
# Source Key:		imgs/train/c0/img_58568.jpg
# Destination Key:	imgs/validation/c0/img_58568.jpg
#
# Source Key:		imgs/train/c0/img_58629.jpg
# Destination Key:	imgs/validation/c0/img_58629.jpg
#
# Source Key:		imgs/train/c0/img_58679.jpg
# Destination Key:	imgs/validation/c0/img_58679.jpg
#
# Source Key:		imgs/train/c0/img_58710.jpg
# Destination Key:	imgs/validation/c0/img_58710.jpg
#
# Source Key:		imgs/train/c0/img_58721.jpg
# Destination Key:	imgs/validation/c0/img_58721.jpg
#
# Source Key:		imgs/train/c0/img_58881.jpg
# Destination Key:	imgs/validation/c0/img_58881.jpg
#
# Source Key:		imgs/train/c0/img_58938.jpg
# Destination Key:	imgs/validation/c0/img_58938.jpg
#
# Source Key:		imgs/train/c0/img_58950.jpg
# Destination Key:	imgs/validation/c0/img_58950.jpg
#
# Source Key:		imgs/train/c0/img_59032.jpg
# Destination Key:	imgs/validation/c0/img_59032.jpg
#
# Source Key:		imgs/train/c0/img_59118.jpg
# Destination Key:	imgs/validation/c0/img_59118.jpg
#
# Source Key:		imgs/train/c0/img_59237.jpg
# Destination Key:	imgs/validation/c0/img_59237.jpg
#
# Source Key:		imgs/train/c0/img_5929.jpg
# Destination Key:	imgs/validation/c0/img_5929.jpg
#
# Source Key:		imgs/train/c0/img_59322.jpg
# Destination Key:	imgs/validation/c0/img_59322.jpg
#
# Source Key:		imgs/train/c0/img_59561.jpg
# Destination Key:	imgs/validation/c0/img_59561.jpg
#
# Source Key:		imgs/train/c0/img_5957.jpg
# Destination Key:	imgs/validation/c0/img_5957.jpg
#
# Source Key:		imgs/train/c0/img_59570.jpg
# Destination Key:	imgs/validation/c0/img_59570.jpg
#
# Source Key:		imgs/train/c0/img_59764.jpg
# Destination Key:	imgs/validation/c0/img_59764.jpg
#
# Source Key:		imgs/train/c0/img_59772.jpg
# Destination Key:	imgs/validation/c0/img_59772.jpg
#
# Source Key:		imgs/train/c0/img_59778.jpg
# Destination Key:	imgs/validation/c0/img_59778.jpg
#
# Source Key:		imgs/train/c0/img_59992.jpg
# Destination Key:	imgs/validation/c0/img_59992.jpg
#
# Source Key:		imgs/train/c0/img_60026.jpg
# Destination Key:	imgs/validation/c0/img_60026.jpg
#
# Source Key:		imgs/train/c0/img_60063.jpg
# Destination Key:	imgs/validation/c0/img_60063.jpg
#
# Source Key:		imgs/train/c0/img_60168.jpg
# Destination Key:	imgs/validation/c0/img_60168.jpg
#
# Source Key:		imgs/train/c0/img_60651.jpg
# Destination Key:	imgs/validation/c0/img_60651.jpg
#
# Source Key:		imgs/train/c0/img_60835.jpg
# Destination Key:	imgs/validation/c0/img_60835.jpg
#
# Source Key:		imgs/train/c0/img_60925.jpg
# Destination Key:	imgs/validation/c0/img_60925.jpg
#
# Source Key:		imgs/train/c0/img_60928.jpg
# Destination Key:	imgs/validation/c0/img_60928.jpg
#
# Source Key:		imgs/train/c0/img_61373.jpg
# Destination Key:	imgs/validation/c0/img_61373.jpg
#
# Source Key:		imgs/train/c0/img_61568.jpg
# Destination Key:	imgs/validation/c0/img_61568.jpg
#
# Source Key:		imgs/train/c0/img_61737.jpg
# Destination Key:	imgs/validation/c0/img_61737.jpg
#
# Source Key:		imgs/train/c0/img_61869.jpg
# Destination Key:	imgs/validation/c0/img_61869.jpg
#
# Source Key:		imgs/train/c0/img_62066.jpg
# Destination Key:	imgs/validation/c0/img_62066.jpg
#
# Source Key:		imgs/train/c0/img_62129.jpg
# Destination Key:	imgs/validation/c0/img_62129.jpg
#
# Source Key:		imgs/train/c0/img_62631.jpg
# Destination Key:	imgs/validation/c0/img_62631.jpg
#
# Source Key:		imgs/train/c0/img_62781.jpg
# Destination Key:	imgs/validation/c0/img_62781.jpg
#
# Source Key:		imgs/train/c0/img_63023.jpg
# Destination Key:	imgs/validation/c0/img_63023.jpg
#
# Source Key:		imgs/train/c0/img_63073.jpg
# Destination Key:	imgs/validation/c0/img_63073.jpg
#
# Source Key:		imgs/train/c0/img_63140.jpg
# Destination Key:	imgs/validation/c0/img_63140.jpg
#
# Source Key:		imgs/train/c0/img_63314.jpg
# Destination Key:	imgs/validation/c0/img_63314.jpg
#
# Source Key:		imgs/train/c0/img_63345.jpg
# Destination Key:	imgs/validation/c0/img_63345.jpg
#
# Source Key:		imgs/train/c0/img_63414.jpg
# Destination Key:	imgs/validation/c0/img_63414.jpg
#
# Source Key:		imgs/train/c0/img_63634.jpg
# Destination Key:	imgs/validation/c0/img_63634.jpg
#
# Source Key:		imgs/train/c0/img_63812.jpg
# Destination Key:	imgs/validation/c0/img_63812.jpg
#
# Source Key:		imgs/train/c0/img_63842.jpg
# Destination Key:	imgs/validation/c0/img_63842.jpg
#
# Source Key:		imgs/train/c0/img_63904.jpg
# Destination Key:	imgs/validation/c0/img_63904.jpg
#
# Source Key:		imgs/train/c0/img_64030.jpg
# Destination Key:	imgs/validation/c0/img_64030.jpg
#
# Source Key:		imgs/train/c0/img_64106.jpg
# Destination Key:	imgs/validation/c0/img_64106.jpg
#
# Source Key:		imgs/train/c0/img_64276.jpg
# Destination Key:	imgs/validation/c0/img_64276.jpg
#
# Source Key:		imgs/train/c0/img_6461.jpg
# Destination Key:	imgs/validation/c0/img_6461.jpg
#
# Source Key:		imgs/train/c0/img_64635.jpg
# Destination Key:	imgs/validation/c0/img_64635.jpg
#
# Source Key:		imgs/train/c0/img_64638.jpg
# Destination Key:	imgs/validation/c0/img_64638.jpg
#
# Source Key:		imgs/train/c0/img_64681.jpg
# Destination Key:	imgs/validation/c0/img_64681.jpg
#
# Source Key:		imgs/train/c0/img_64755.jpg
# Destination Key:	imgs/validation/c0/img_64755.jpg
#
# Source Key:		imgs/train/c0/img_65060.jpg
# Destination Key:	imgs/validation/c0/img_65060.jpg
#
# Source Key:		imgs/train/c0/img_65097.jpg
# Destination Key:	imgs/validation/c0/img_65097.jpg
#
# Source Key:		imgs/train/c0/img_65344.jpg
# Destination Key:	imgs/validation/c0/img_65344.jpg
#
# Source Key:		imgs/train/c0/img_65371.jpg
# Destination Key:	imgs/validation/c0/img_65371.jpg
#
# Source Key:		imgs/train/c0/img_65497.jpg
# Destination Key:	imgs/validation/c0/img_65497.jpg
#
# Source Key:		imgs/train/c0/img_65583.jpg
# Destination Key:	imgs/validation/c0/img_65583.jpg
#
# Source Key:		imgs/train/c0/img_65599.jpg
# Destination Key:	imgs/validation/c0/img_65599.jpg
#
# Source Key:		imgs/train/c0/img_656.jpg
# Destination Key:	imgs/validation/c0/img_656.jpg
#
# Source Key:		imgs/train/c0/img_65697.jpg
# Destination Key:	imgs/validation/c0/img_65697.jpg
#
# Source Key:		imgs/train/c0/img_65833.jpg
# Destination Key:	imgs/validation/c0/img_65833.jpg
#
# Source Key:		imgs/train/c0/img_65901.jpg
# Destination Key:	imgs/validation/c0/img_65901.jpg
#
# Source Key:		imgs/train/c0/img_65981.jpg
# Destination Key:	imgs/validation/c0/img_65981.jpg
#
# Source Key:		imgs/train/c0/img_66010.jpg
# Destination Key:	imgs/validation/c0/img_66010.jpg
#
# Source Key:		imgs/train/c0/img_6614.jpg
# Destination Key:	imgs/validation/c0/img_6614.jpg
#
# Source Key:		imgs/train/c0/img_66490.jpg
# Destination Key:	imgs/validation/c0/img_66490.jpg
#
# Source Key:		imgs/train/c0/img_66723.jpg
# Destination Key:	imgs/validation/c0/img_66723.jpg
#
# Source Key:		imgs/train/c0/img_66814.jpg
# Destination Key:	imgs/validation/c0/img_66814.jpg
#
# Source Key:		imgs/train/c0/img_66819.jpg
# Destination Key:	imgs/validation/c0/img_66819.jpg
#
# Source Key:		imgs/train/c0/img_66888.jpg
# Destination Key:	imgs/validation/c0/img_66888.jpg
#
# Source Key:		imgs/train/c0/img_66982.jpg
# Destination Key:	imgs/validation/c0/img_66982.jpg
#
# Source Key:		imgs/train/c0/img_66990.jpg
# Destination Key:	imgs/validation/c0/img_66990.jpg
#
# Source Key:		imgs/train/c0/img_67092.jpg
# Destination Key:	imgs/validation/c0/img_67092.jpg
#
# Source Key:		imgs/train/c0/img_67219.jpg
# Destination Key:	imgs/validation/c0/img_67219.jpg
#
# Source Key:		imgs/train/c0/img_67811.jpg
# Destination Key:	imgs/validation/c0/img_67811.jpg
#
# Source Key:		imgs/train/c0/img_67865.jpg
# Destination Key:	imgs/validation/c0/img_67865.jpg
#
# Source Key:		imgs/train/c0/img_67875.jpg
# Destination Key:	imgs/validation/c0/img_67875.jpg
#
# Source Key:		imgs/train/c0/img_68181.jpg
# Destination Key:	imgs/validation/c0/img_68181.jpg
#
# Source Key:		imgs/train/c0/img_68227.jpg
# Destination Key:	imgs/validation/c0/img_68227.jpg
#
# Source Key:		imgs/train/c0/img_68539.jpg
# Destination Key:	imgs/validation/c0/img_68539.jpg
#
# Source Key:		imgs/train/c0/img_68746.jpg
# Destination Key:	imgs/validation/c0/img_68746.jpg
#
# Source Key:		imgs/train/c0/img_68766.jpg
# Destination Key:	imgs/validation/c0/img_68766.jpg
#
# Source Key:		imgs/train/c0/img_68933.jpg
# Destination Key:	imgs/validation/c0/img_68933.jpg
#
# Source Key:		imgs/train/c0/img_68999.jpg
# Destination Key:	imgs/validation/c0/img_68999.jpg
#
# Source Key:		imgs/train/c0/img_69183.jpg
# Destination Key:	imgs/validation/c0/img_69183.jpg
#
# Source Key:		imgs/train/c0/img_69446.jpg
# Destination Key:	imgs/validation/c0/img_69446.jpg
#
# Source Key:		imgs/train/c0/img_69558.jpg
# Destination Key:	imgs/validation/c0/img_69558.jpg
#
# Source Key:		imgs/train/c0/img_69697.jpg
# Destination Key:	imgs/validation/c0/img_69697.jpg
#
# Source Key:		imgs/train/c0/img_69702.jpg
# Destination Key:	imgs/validation/c0/img_69702.jpg
#
# Source Key:		imgs/train/c0/img_70032.jpg
# Destination Key:	imgs/validation/c0/img_70032.jpg
#
# Source Key:		imgs/train/c0/img_70144.jpg
# Destination Key:	imgs/validation/c0/img_70144.jpg
#
# Source Key:		imgs/train/c0/img_70230.jpg
# Destination Key:	imgs/validation/c0/img_70230.jpg
#
# Source Key:		imgs/train/c0/img_70406.jpg
# Destination Key:	imgs/validation/c0/img_70406.jpg
#
# Source Key:		imgs/train/c0/img_70417.jpg
# Destination Key:	imgs/validation/c0/img_70417.jpg
#
# Source Key:		imgs/train/c0/img_70421.jpg
# Destination Key:	imgs/validation/c0/img_70421.jpg
#
# Source Key:		imgs/train/c0/img_70429.jpg
# Destination Key:	imgs/validation/c0/img_70429.jpg
#
# Source Key:		imgs/train/c0/img_70442.jpg
# Destination Key:	imgs/validation/c0/img_70442.jpg
#
# Source Key:		imgs/train/c0/img_71021.jpg
# Destination Key:	imgs/validation/c0/img_71021.jpg
#
# Source Key:		imgs/train/c0/img_71045.jpg
# Destination Key:	imgs/validation/c0/img_71045.jpg
#
# Source Key:		imgs/train/c0/img_71091.jpg
# Destination Key:	imgs/validation/c0/img_71091.jpg
#
# Source Key:		imgs/train/c0/img_71138.jpg
# Destination Key:	imgs/validation/c0/img_71138.jpg
#
# Source Key:		imgs/train/c0/img_71160.jpg
# Destination Key:	imgs/validation/c0/img_71160.jpg
#
# Source Key:		imgs/train/c0/img_71214.jpg
# Destination Key:	imgs/validation/c0/img_71214.jpg
#
# Source Key:		imgs/train/c0/img_71304.jpg
# Destination Key:	imgs/validation/c0/img_71304.jpg
#
# Source Key:		imgs/train/c0/img_71387.jpg
# Destination Key:	imgs/validation/c0/img_71387.jpg
#
# Source Key:		imgs/train/c0/img_71758.jpg
# Destination Key:	imgs/validation/c0/img_71758.jpg
#
# Source Key:		imgs/train/c0/img_71760.jpg
# Destination Key:	imgs/validation/c0/img_71760.jpg
#
# Source Key:		imgs/train/c0/img_71768.jpg
# Destination Key:	imgs/validation/c0/img_71768.jpg
#
# Source Key:		imgs/train/c0/img_71815.jpg
# Destination Key:	imgs/validation/c0/img_71815.jpg
#
# Source Key:		imgs/train/c0/img_71951.jpg
# Destination Key:	imgs/validation/c0/img_71951.jpg
#
# Source Key:		imgs/train/c0/img_72204.jpg
# Destination Key:	imgs/validation/c0/img_72204.jpg
#
# Source Key:		imgs/train/c0/img_72276.jpg
# Destination Key:	imgs/validation/c0/img_72276.jpg
#
# Source Key:		imgs/train/c0/img_72492.jpg
# Destination Key:	imgs/validation/c0/img_72492.jpg
#
# Source Key:		imgs/train/c0/img_72493.jpg
# Destination Key:	imgs/validation/c0/img_72493.jpg
#
# Source Key:		imgs/train/c0/img_72543.jpg
# Destination Key:	imgs/validation/c0/img_72543.jpg
#
# Source Key:		imgs/train/c0/img_72599.jpg
# Destination Key:	imgs/validation/c0/img_72599.jpg
#
# Source Key:		imgs/train/c0/img_72668.jpg
# Destination Key:	imgs/validation/c0/img_72668.jpg
#
# Source Key:		imgs/train/c0/img_7272.jpg
# Destination Key:	imgs/validation/c0/img_7272.jpg
#
# Source Key:		imgs/train/c0/img_72874.jpg
# Destination Key:	imgs/validation/c0/img_72874.jpg
#
# Source Key:		imgs/train/c0/img_73127.jpg
# Destination Key:	imgs/validation/c0/img_73127.jpg
#
# Source Key:		imgs/train/c0/img_73423.jpg
# Destination Key:	imgs/validation/c0/img_73423.jpg
#
# Source Key:		imgs/train/c0/img_73468.jpg
# Destination Key:	imgs/validation/c0/img_73468.jpg
#
# Source Key:		imgs/train/c0/img_73479.jpg
# Destination Key:	imgs/validation/c0/img_73479.jpg
#
# Source Key:		imgs/train/c0/img_73626.jpg
# Destination Key:	imgs/validation/c0/img_73626.jpg
#
# Source Key:		imgs/train/c0/img_73679.jpg
# Destination Key:	imgs/validation/c0/img_73679.jpg
#
# Source Key:		imgs/train/c0/img_74002.jpg
# Destination Key:	imgs/validation/c0/img_74002.jpg
#
# Source Key:		imgs/train/c0/img_74351.jpg
# Destination Key:	imgs/validation/c0/img_74351.jpg
#
# Source Key:		imgs/train/c0/img_74374.jpg
# Destination Key:	imgs/validation/c0/img_74374.jpg
#
# Source Key:		imgs/train/c0/img_74590.jpg
# Destination Key:	imgs/validation/c0/img_74590.jpg
#
# Source Key:		imgs/train/c0/img_7473.jpg
# Destination Key:	imgs/validation/c0/img_7473.jpg
#
# Source Key:		imgs/train/c0/img_74751.jpg
# Destination Key:	imgs/validation/c0/img_74751.jpg
#
# Source Key:		imgs/train/c0/img_75168.jpg
# ...
#
# Source Key:		imgs/train/c9/img_75061.jpg
# Destination Key:	imgs/validation/c9/img_75061.jpg
#
# Source Key:		imgs/train/c9/img_75215.jpg
# Destination Key:	imgs/validation/c9/img_75215.jpg
#
# Source Key:		imgs/train/c9/img_75327.jpg
# Destination Key:	imgs/validation/c9/img_75327.jpg
#
# Source Key:		imgs/train/c9/img_75408.jpg
# Destination Key:	imgs/validation/c9/img_75408.jpg
#
# Source Key:		imgs/train/c9/img_75520.jpg
# Destination Key:	imgs/validation/c9/img_75520.jpg
#
# Source Key:		imgs/train/c9/img_75551.jpg
# Destination Key:	imgs/validation/c9/img_75551.jpg
#
# Source Key:		imgs/train/c9/img_75562.jpg
# Destination Key:	imgs/validation/c9/img_75562.jpg
#
# Source Key:		imgs/train/c9/img_75655.jpg
# Destination Key:	imgs/validation/c9/img_75655.jpg
#
# Source Key:		imgs/train/c9/img_75666.jpg
# Destination Key:	imgs/validation/c9/img_75666.jpg
#
# Source Key:		imgs/train/c9/img_75671.jpg
# Destination Key:	imgs/validation/c9/img_75671.jpg
#
# Source Key:		imgs/train/c9/img_75875.jpg
# Destination Key:	imgs/validation/c9/img_75875.jpg
#
# Source Key:		imgs/train/c9/img_76204.jpg
# Destination Key:	imgs/validation/c9/img_76204.jpg
#
# Source Key:		imgs/train/c9/img_76230.jpg
# Destination Key:	imgs/validation/c9/img_76230.jpg
#
# Source Key:		imgs/train/c9/img_763.jpg
# Destination Key:	imgs/validation/c9/img_763.jpg
#
# Source Key:		imgs/train/c9/img_76510.jpg
# Destination Key:	imgs/validation/c9/img_76510.jpg
#
# Source Key:		imgs/train/c9/img_76688.jpg
# Destination Key:	imgs/validation/c9/img_76688.jpg
#
# Source Key:		imgs/train/c9/img_769.jpg
# Destination Key:	imgs/validation/c9/img_769.jpg
#
# Source Key:		imgs/train/c9/img_77138.jpg
# Destination Key:	imgs/validation/c9/img_77138.jpg
#
# Source Key:		imgs/train/c9/img_77191.jpg
# Destination Key:	imgs/validation/c9/img_77191.jpg
#
# Source Key:		imgs/train/c9/img_77467.jpg
# Destination Key:	imgs/validation/c9/img_77467.jpg
#
# Source Key:		imgs/train/c9/img_77505.jpg
# Destination Key:	imgs/validation/c9/img_77505.jpg
#
# Source Key:		imgs/train/c9/img_77820.jpg
# Destination Key:	imgs/validation/c9/img_77820.jpg
#
# Source Key:		imgs/train/c9/img_77988.jpg
# Destination Key:	imgs/validation/c9/img_77988.jpg
#
# Source Key:		imgs/train/c9/img_7801.jpg
# Destination Key:	imgs/validation/c9/img_7801.jpg
#
# Source Key:		imgs/train/c9/img_78692.jpg
# Destination Key:	imgs/validation/c9/img_78692.jpg
#
# Source Key:		imgs/train/c9/img_78976.jpg
# Destination Key:	imgs/validation/c9/img_78976.jpg
#
# Source Key:		imgs/train/c9/img_79034.jpg
# Destination Key:	imgs/validation/c9/img_79034.jpg
#
# Source Key:		imgs/train/c9/img_79178.jpg
# Destination Key:	imgs/validation/c9/img_79178.jpg
#
# Source Key:		imgs/train/c9/img_7918.jpg
# Destination Key:	imgs/validation/c9/img_7918.jpg
#
# Source Key:		imgs/train/c9/img_79393.jpg
# Destination Key:	imgs/validation/c9/img_79393.jpg
#
# Source Key:		imgs/train/c9/img_79471.jpg
# Destination Key:	imgs/validation/c9/img_79471.jpg
#
# Source Key:		imgs/train/c9/img_79596.jpg
# Destination Key:	imgs/validation/c9/img_79596.jpg
#
# Source Key:		imgs/train/c9/img_79944.jpg
# Destination Key:	imgs/validation/c9/img_79944.jpg
#
# Source Key:		imgs/train/c9/img_79977.jpg
# Destination Key:	imgs/validation/c9/img_79977.jpg
#
# Source Key:		imgs/train/c9/img_79994.jpg
# Destination Key:	imgs/validation/c9/img_79994.jpg
#
# Source Key:		imgs/train/c9/img_80089.jpg
# Destination Key:	imgs/validation/c9/img_80089.jpg
#
# Source Key:		imgs/train/c9/img_80387.jpg
# Destination Key:	imgs/validation/c9/img_80387.jpg
#
# Source Key:		imgs/train/c9/img_8044.jpg
# Destination Key:	imgs/validation/c9/img_8044.jpg
#
# Source Key:		imgs/train/c9/img_80484.jpg
# Destination Key:	imgs/validation/c9/img_80484.jpg
#
# Source Key:		imgs/train/c9/img_80491.jpg
# Destination Key:	imgs/validation/c9/img_80491.jpg
#
# Source Key:		imgs/train/c9/img_80757.jpg
# Destination Key:	imgs/validation/c9/img_80757.jpg
#
# Source Key:		imgs/train/c9/img_80965.jpg
# Destination Key:	imgs/validation/c9/img_80965.jpg
#
# Source Key:		imgs/train/c9/img_81414.jpg
# Destination Key:	imgs/validation/c9/img_81414.jpg
#
# Source Key:		imgs/train/c9/img_81485.jpg
# Destination Key:	imgs/validation/c9/img_81485.jpg
#
# Source Key:		imgs/train/c9/img_81578.jpg
# Destination Key:	imgs/validation/c9/img_81578.jpg
#
# Source Key:		imgs/train/c9/img_81724.jpg
# Destination Key:	imgs/validation/c9/img_81724.jpg
#
# Source Key:		imgs/train/c9/img_81799.jpg
# Destination Key:	imgs/validation/c9/img_81799.jpg
#
# Source Key:		imgs/train/c9/img_81983.jpg
# Destination Key:	imgs/validation/c9/img_81983.jpg
#
# Source Key:		imgs/train/c9/img_82259.jpg
# Destination Key:	imgs/validation/c9/img_82259.jpg
#
# Source Key:		imgs/train/c9/img_82297.jpg
# Destination Key:	imgs/validation/c9/img_82297.jpg
#
# Source Key:		imgs/train/c9/img_82571.jpg
# Destination Key:	imgs/validation/c9/img_82571.jpg
#
# Source Key:		imgs/train/c9/img_82757.jpg
# Destination Key:	imgs/validation/c9/img_82757.jpg
#
# Source Key:		imgs/train/c9/img_82809.jpg
# Destination Key:	imgs/validation/c9/img_82809.jpg
#
# Source Key:		imgs/train/c9/img_82868.jpg
# Destination Key:	imgs/validation/c9/img_82868.jpg
#
# Source Key:		imgs/train/c9/img_83115.jpg
# Destination Key:	imgs/validation/c9/img_83115.jpg
#
# Source Key:		imgs/train/c9/img_83272.jpg
# Destination Key:	imgs/validation/c9/img_83272.jpg
#
# Source Key:		imgs/train/c9/img_83280.jpg
# Destination Key:	imgs/validation/c9/img_83280.jpg
#
# Source Key:		imgs/train/c9/img_83320.jpg
# Destination Key:	imgs/validation/c9/img_83320.jpg
#
# Source Key:		imgs/train/c9/img_8335.jpg
# Destination Key:	imgs/validation/c9/img_8335.jpg
#
# Source Key:		imgs/train/c9/img_83477.jpg
# Destination Key:	imgs/validation/c9/img_83477.jpg
#
# Source Key:		imgs/train/c9/img_83500.jpg
# Destination Key:	imgs/validation/c9/img_83500.jpg
#
# Source Key:		imgs/train/c9/img_83528.jpg
# Destination Key:	imgs/validation/c9/img_83528.jpg
#
# Source Key:		imgs/train/c9/img_83611.jpg
# Destination Key:	imgs/validation/c9/img_83611.jpg
#
# Source Key:		imgs/train/c9/img_83616.jpg
# Destination Key:	imgs/validation/c9/img_83616.jpg
#
# Source Key:		imgs/train/c9/img_83649.jpg
# Destination Key:	imgs/validation/c9/img_83649.jpg
#
# Source Key:		imgs/train/c9/img_83868.jpg
# Destination Key:	imgs/validation/c9/img_83868.jpg
#
# Source Key:		imgs/train/c9/img_84132.jpg
# Destination Key:	imgs/validation/c9/img_84132.jpg
#
# Source Key:		imgs/train/c9/img_84168.jpg
# Destination Key:	imgs/validation/c9/img_84168.jpg
#
# Source Key:		imgs/train/c9/img_84455.jpg
# Destination Key:	imgs/validation/c9/img_84455.jpg
#
# Source Key:		imgs/train/c9/img_84544.jpg
# Destination Key:	imgs/validation/c9/img_84544.jpg
#
# Source Key:		imgs/train/c9/img_84628.jpg
# Destination Key:	imgs/validation/c9/img_84628.jpg
#
# Source Key:		imgs/train/c9/img_84733.jpg
# Destination Key:	imgs/validation/c9/img_84733.jpg
#
# Source Key:		imgs/train/c9/img_84734.jpg
# Destination Key:	imgs/validation/c9/img_84734.jpg
#
# Source Key:		imgs/train/c9/img_8480.jpg
# Destination Key:	imgs/validation/c9/img_8480.jpg
#
# Source Key:		imgs/train/c9/img_8484.jpg
# Destination Key:	imgs/validation/c9/img_8484.jpg
#
# Source Key:		imgs/train/c9/img_84918.jpg
# Destination Key:	imgs/validation/c9/img_84918.jpg
#
# Source Key:		imgs/train/c9/img_85062.jpg
# Destination Key:	imgs/validation/c9/img_85062.jpg
#
# Source Key:		imgs/train/c9/img_85449.jpg
# Destination Key:	imgs/validation/c9/img_85449.jpg
#
# Source Key:		imgs/train/c9/img_85699.jpg
# Destination Key:	imgs/validation/c9/img_85699.jpg
#
# Source Key:		imgs/train/c9/img_85817.jpg
# Destination Key:	imgs/validation/c9/img_85817.jpg
#
# Source Key:		imgs/train/c9/img_85835.jpg
# Destination Key:	imgs/validation/c9/img_85835.jpg
#
# Source Key:		imgs/train/c9/img_85876.jpg
# Destination Key:	imgs/validation/c9/img_85876.jpg
#
# Source Key:		imgs/train/c9/img_85997.jpg
# Destination Key:	imgs/validation/c9/img_85997.jpg
#
# Source Key:		imgs/train/c9/img_8601.jpg
# Destination Key:	imgs/validation/c9/img_8601.jpg
#
# Source Key:		imgs/train/c9/img_86713.jpg
# Destination Key:	imgs/validation/c9/img_86713.jpg
#
# Source Key:		imgs/train/c9/img_86751.jpg
# Destination Key:	imgs/validation/c9/img_86751.jpg
#
# Source Key:		imgs/train/c9/img_86782.jpg
# Destination Key:	imgs/validation/c9/img_86782.jpg
#
# Source Key:		imgs/train/c9/img_86924.jpg
# Destination Key:	imgs/validation/c9/img_86924.jpg
#
# Source Key:		imgs/train/c9/img_86985.jpg
# Destination Key:	imgs/validation/c9/img_86985.jpg
#
# Source Key:		imgs/train/c9/img_87154.jpg
# Destination Key:	imgs/validation/c9/img_87154.jpg
#
# Source Key:		imgs/train/c9/img_87721.jpg
# Destination Key:	imgs/validation/c9/img_87721.jpg
#
# Source Key:		imgs/train/c9/img_87785.jpg
# Destination Key:	imgs/validation/c9/img_87785.jpg
#
# Source Key:		imgs/train/c9/img_87927.jpg
# Destination Key:	imgs/validation/c9/img_87927.jpg
#
# Source Key:		imgs/train/c9/img_88570.jpg
# Destination Key:	imgs/validation/c9/img_88570.jpg
#
# Source Key:		imgs/train/c9/img_88683.jpg
# Destination Key:	imgs/validation/c9/img_88683.jpg
#
# Source Key:		imgs/train/c9/img_88717.jpg
# Destination Key:	imgs/validation/c9/img_88717.jpg
#
# Source Key:		imgs/train/c9/img_88722.jpg
# Destination Key:	imgs/validation/c9/img_88722.jpg
#
# Source Key:		imgs/train/c9/img_89022.jpg
# Destination Key:	imgs/validation/c9/img_89022.jpg
#
# Source Key:		imgs/train/c9/img_89106.jpg
# Destination Key:	imgs/validation/c9/img_89106.jpg
#
# Source Key:		imgs/train/c9/img_89116.jpg
# Destination Key:	imgs/validation/c9/img_89116.jpg
#
# Source Key:		imgs/train/c9/img_89346.jpg
# Destination Key:	imgs/validation/c9/img_89346.jpg
#
# Source Key:		imgs/train/c9/img_89399.jpg
# Destination Key:	imgs/validation/c9/img_89399.jpg
#
# Source Key:		imgs/train/c9/img_89446.jpg
# Destination Key:	imgs/validation/c9/img_89446.jpg
#
# Source Key:		imgs/train/c9/img_89575.jpg
# Destination Key:	imgs/validation/c9/img_89575.jpg
#
# Source Key:		imgs/train/c9/img_89593.jpg
# Destination Key:	imgs/validation/c9/img_89593.jpg
#
# Source Key:		imgs/train/c9/img_89657.jpg
# Destination Key:	imgs/validation/c9/img_89657.jpg
#
# Source Key:		imgs/train/c9/img_89877.jpg
# Destination Key:	imgs/validation/c9/img_89877.jpg
#
# Source Key:		imgs/train/c9/img_90058.jpg
# Destination Key:	imgs/validation/c9/img_90058.jpg
#
# Source Key:		imgs/train/c9/img_90370.jpg
# Destination Key:	imgs/validation/c9/img_90370.jpg
#
# Source Key:		imgs/train/c9/img_90595.jpg
# Destination Key:	imgs/validation/c9/img_90595.jpg
#
# Source Key:		imgs/train/c9/img_90851.jpg
# Destination Key:	imgs/validation/c9/img_90851.jpg
#
# Source Key:		imgs/train/c9/img_91002.jpg
# Destination Key:	imgs/validation/c9/img_91002.jpg
#
# Source Key:		imgs/train/c9/img_91117.jpg
# Destination Key:	imgs/validation/c9/img_91117.jpg
#
# Source Key:		imgs/train/c9/img_91137.jpg
# Destination Key:	imgs/validation/c9/img_91137.jpg
#
# Source Key:		imgs/train/c9/img_91312.jpg
# Destination Key:	imgs/validation/c9/img_91312.jpg
#
# Source Key:		imgs/train/c9/img_91422.jpg
# Destination Key:	imgs/validation/c9/img_91422.jpg
#
# Source Key:		imgs/train/c9/img_91430.jpg
# Destination Key:	imgs/validation/c9/img_91430.jpg
#
# Source Key:		imgs/train/c9/img_9151.jpg
# Destination Key:	imgs/validation/c9/img_9151.jpg
#
# Source Key:		imgs/train/c9/img_91514.jpg
# Destination Key:	imgs/validation/c9/img_91514.jpg
#
# Source Key:		imgs/train/c9/img_91798.jpg
# Destination Key:	imgs/validation/c9/img_91798.jpg
#
# Source Key:		imgs/train/c9/img_91822.jpg
# Destination Key:	imgs/validation/c9/img_91822.jpg
#
# Source Key:		imgs/train/c9/img_91839.jpg
# Destination Key:	imgs/validation/c9/img_91839.jpg
#
# Source Key:		imgs/train/c9/img_91897.jpg
# Destination Key:	imgs/validation/c9/img_91897.jpg
#
# Source Key:		imgs/train/c9/img_91970.jpg
# Destination Key:	imgs/validation/c9/img_91970.jpg
#
# Source Key:		imgs/train/c9/img_92023.jpg
# Destination Key:	imgs/validation/c9/img_92023.jpg
#
# Source Key:		imgs/train/c9/img_9215.jpg
# Destination Key:	imgs/validation/c9/img_9215.jpg
#
# Source Key:		imgs/train/c9/img_92404.jpg
# Destination Key:	imgs/validation/c9/img_92404.jpg
#
# Source Key:		imgs/train/c9/img_92741.jpg
# Destination Key:	imgs/validation/c9/img_92741.jpg
#
# Source Key:		imgs/train/c9/img_93073.jpg
# Destination Key:	imgs/validation/c9/img_93073.jpg
#
# Source Key:		imgs/train/c9/img_93288.jpg
# Destination Key:	imgs/validation/c9/img_93288.jpg
#
# Source Key:		imgs/train/c9/img_93592.jpg
# Destination Key:	imgs/validation/c9/img_93592.jpg
#
# Source Key:		imgs/train/c9/img_93669.jpg
# Destination Key:	imgs/validation/c9/img_93669.jpg
#
# Source Key:		imgs/train/c9/img_93918.jpg
# Destination Key:	imgs/validation/c9/img_93918.jpg
#
# Source Key:		imgs/train/c9/img_94148.jpg
# Destination Key:	imgs/validation/c9/img_94148.jpg
#
# Source Key:		imgs/train/c9/img_94377.jpg
# Destination Key:	imgs/validation/c9/img_94377.jpg
#
# Source Key:		imgs/train/c9/img_94439.jpg
# Destination Key:	imgs/validation/c9/img_94439.jpg
#
# Source Key:		imgs/train/c9/img_94971.jpg
# Destination Key:	imgs/validation/c9/img_94971.jpg
#
# Source Key:		imgs/train/c9/img_95005.jpg
# Destination Key:	imgs/validation/c9/img_95005.jpg
#
# Source Key:		imgs/train/c9/img_95108.jpg
# Destination Key:	imgs/validation/c9/img_95108.jpg
#
# Source Key:		imgs/train/c9/img_9512.jpg
# Destination Key:	imgs/validation/c9/img_9512.jpg
#
# Source Key:		imgs/train/c9/img_95184.jpg
# Destination Key:	imgs/validation/c9/img_95184.jpg
#
# Source Key:		imgs/train/c9/img_95619.jpg
# Destination Key:	imgs/validation/c9/img_95619.jpg
#
# Source Key:		imgs/train/c9/img_95624.jpg
# Destination Key:	imgs/validation/c9/img_95624.jpg
#
# Source Key:		imgs/train/c9/img_95671.jpg
# Destination Key:	imgs/validation/c9/img_95671.jpg
#
# Source Key:		imgs/train/c9/img_95888.jpg
# Destination Key:	imgs/validation/c9/img_95888.jpg
#
# Source Key:		imgs/train/c9/img_95900.jpg
# Destination Key:	imgs/validation/c9/img_95900.jpg
#
# Source Key:		imgs/train/c9/img_96054.jpg
# Destination Key:	imgs/validation/c9/img_96054.jpg
#
# Source Key:		imgs/train/c9/img_96189.jpg
# Destination Key:	imgs/validation/c9/img_96189.jpg
#
# Source Key:		imgs/train/c9/img_96266.jpg
# Destination Key:	imgs/validation/c9/img_96266.jpg
#
# Source Key:		imgs/train/c9/img_9634.jpg
# Destination Key:	imgs/validation/c9/img_9634.jpg
#
# Source Key:		imgs/train/c9/img_96491.jpg
# Destination Key:	imgs/validation/c9/img_96491.jpg
#
# Source Key:		imgs/train/c9/img_96825.jpg
# Destination Key:	imgs/validation/c9/img_96825.jpg
#
# Source Key:		imgs/train/c9/img_96877.jpg
# Destination Key:	imgs/validation/c9/img_96877.jpg
#
# Source Key:		imgs/train/c9/img_97105.jpg
# Destination Key:	imgs/validation/c9/img_97105.jpg
#
# Source Key:		imgs/train/c9/img_97229.jpg
# Destination Key:	imgs/validation/c9/img_97229.jpg
#
# Source Key:		imgs/train/c9/img_97274.jpg
# Destination Key:	imgs/validation/c9/img_97274.jpg
#
# Source Key:		imgs/train/c9/img_97287.jpg
# Destination Key:	imgs/validation/c9/img_97287.jpg
#
# Source Key:		imgs/train/c9/img_97500.jpg
# Destination Key:	imgs/validation/c9/img_97500.jpg
#
# Source Key:		imgs/train/c9/img_97580.jpg
# Destination Key:	imgs/validation/c9/img_97580.jpg
#
# Source Key:		imgs/train/c9/img_97749.jpg
# Destination Key:	imgs/validation/c9/img_97749.jpg
#
# Source Key:		imgs/train/c9/img_9777.jpg
# Destination Key:	imgs/validation/c9/img_9777.jpg
#
# Source Key:		imgs/train/c9/img_97999.jpg
# Destination Key:	imgs/validation/c9/img_97999.jpg
#
# Source Key:		imgs/train/c9/img_98205.jpg
# Destination Key:	imgs/validation/c9/img_98205.jpg
#
# Source Key:		imgs/train/c9/img_98618.jpg
# Destination Key:	imgs/validation/c9/img_98618.jpg
#
# Source Key:		imgs/train/c9/img_98731.jpg
# Destination Key:	imgs/validation/c9/img_98731.jpg
#
# Source Key:		imgs/train/c9/img_98741.jpg
# Destination Key:	imgs/validation/c9/img_98741.jpg
#
# Source Key:		imgs/train/c9/img_99044.jpg
# Destination Key:	imgs/validation/c9/img_99044.jpg
#
# Source Key:		imgs/train/c9/img_99104.jpg
# Destination Key:	imgs/validation/c9/img_99104.jpg
#
# Source Key:		imgs/train/c9/img_99295.jpg
# Destination Key:	imgs/validation/c9/img_99295.jpg
#
# Source Key:		imgs/train/c9/img_99569.jpg
# Destination Key:	imgs/validation/c9/img_99569.jpg
#
# Source Key:		imgs/train/c9/img_99740.jpg
# Destination Key:	imgs/validation/c9/img_99740.jpg
#
# Source Key:		imgs/train/c9/img_99927.jpg
# Destination Key:	imgs/validation/c9/img_99927.jpg
#
# Source Key:		imgs/train/c9/img_9993.jpg
# Destination Key:	imgs/validation/c9/img_9993.jpg
#
# Source Key:		imgs/train/c9/img_99949.jpg
# Destination Key:	imgs/validation/c9/img_99949.jpg

# %% [markdown]
# The iteration test appears to have worked correctly. The image traning and validation file locations appear to be correct. To further test we will attacm to copy a file between S3 locations.
#
# To copy a file within a bucket, we will use the **copy_object** function within a S3 client.

# %%
# Inputs
copy_source = {
    "Bucket": bucket,
    "Key": src_key
}

dest_key = dst_key

print("Bucket: {}".format(bucket))
print("Copy Source: {}".format(copy_source))
print("Destination Key: {}".format(dest_key))
# Out:
# Bucket: dsba-6190-final-team-project
# Copy Source: {'Bucket': 'dsba-6190-final-team-project', 'Key': 'imgs/train/c9/img_99949.jpg'}
# Destination Key: imgs/validation/c9/img_99949.jpg

# %% [markdown]
# In order to prevent rerunning a process heavy code chunk, and incurring unnessary AWS fees, I have commented out the following chunk after the initial run.

# %%
'''
for index, row in df_val_lst.iterrows():
    src_key = os.path.join(prefix_train, row['location']).replace("\\","/")
    dest_key = os.path.join(prefix_val, row['location']).replace("\\","/")
    
    # Function Inputs
    copy_source = {
        "Bucket": bucket,
        "Key": src_key
    }
    
    dest_key = dest_key
    
    # Copy
    s3.copy_object(Bucket = bucket,
                   CopySource = copy_source,
                   Key = dest_key)

    # Delete
    s3.delete_object(Bucket = bucket,
                     Key = src_key)
'''
# Out:
# '\nfor index, row in df_val_lst.iterrows():\n    src_key = os.path.join(prefix_train, row[\'location\']).replace("\\","/")\n    dest_key = os.path.join(prefix_val, row[\'location\']).replace("\\","/")\n    \n    # Function Inputs\n    copy_source = {\n        "Bucket": bucket,\n        "Key": src_key\n    }\n    \n    dest_key = dest_key\n    \n    # Copy\n    s3.copy_object(Bucket = bucket,\n                   CopySource = copy_source,\n                   Key = dest_key)\n\n    # Delete\n    s3.delete_object(Bucket = bucket,\n                     Key = src_key)\n'

# %% [markdown]
# ### Copy LST Files
# In order to copy files from our local directory to the correct S3 location, we'll need to us an S3 resource, as opposed to the S3 client used to move images.

# %%
s3_resource = session.resource('s3')

# %% [markdown]
# We will need to define where the LST files are going, and where they are located locally.

# %%
# S3 Locations
train_lst_key = "imgs/train_lst/train.lst"
validation_lst_key = "imgs/validation_lst/validation.lst"

#Local
train_lst_local = "lst_files/train.lst"
validation_lst_local = "lst_files/validation.lst"

# %%
# Training
#s3_resource.Bucket(bucket).upload_file(Filename=train_lst_local,
#                                      Key = train_lst_key)

# %%
# Validation
#s3_resource.Bucket(bucket).upload_file(Filename=validation_lst_local,
#                                      Key = validation_lst_key)
